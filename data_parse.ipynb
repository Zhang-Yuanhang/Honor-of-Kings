# %%
import requests
import pandas as pd
import numpy as np
import warnings
import json
from pandas import json_normalize

warnings.filterwarnings("ignore")

pd.set_option("display.max_rows",100)
pd.set_option("display.max_columns",100)

# %%
BASE_URL = "https://api.91m.top/hero/v1"

# %%
test_url = "https://api.91m.top/hero/app?type=getRanking&aid=0&bid=0&cid=0&did=0"

response = requests.get(test_url)
data_res = json.loads(response.text)

# %%
result_df = json_normalize(data_res['data']['result']['rows']).replace({"--":0})

# %%
result_df[result_df['type'].apply(lambda x:4 in x)].sort_values(by="allPickRate",ascending=False)
# Out:
#          allBanRate  allPickRate  allWinRate  allBPRate  allScore  \
# 13   [27.54, 25.48]        23.57       49.86      49.05    103.93
# 18      [6.1, 6.03]        22.14       50.25      28.17     76.94
# 19     [5.24, 5.15]        19.57       51.22      24.72     71.21
# 11   [34.84, 31.73]        15.88       49.45      47.61     96.17
# 29     [1.97, 1.96]        14.33       49.82      16.29     56.03
# 31      [2.51, 2.5]        12.81       48.79      15.31     53.16
# 14   [47.55, 41.54]        12.37       49.65      53.91    101.50
# 27    [11.28, 10.9]        11.53       49.83      22.43     61.61
# 6    [82.26, 64.73]        10.13       53.04      74.86    127.71
# 42     [0.41, 0.41]         9.30       51.98       9.71     45.12
# 45     [0.46, 0.46]         8.79       52.45       9.25     44.40
# 43     [2.81, 2.78]         5.62       53.07       8.40     41.26
# 52     [0.02, 0.02]         5.56       51.21       5.57     36.76
# 67     [0.07, 0.07]         5.15       50.71       5.22     35.76
# 57     [0.06, 0.06]         4.79       47.30       4.84     33.32
# 75     [0.09, 0.09]         4.76       47.66       4.84     33.48
# 72     [0.03, 0.03]         4.72       48.04       4.75     33.51
# 71     [0.01, 0.01]         4.48       50.54       4.49     34.27
# 69     [0.04, 0.04]         4.44       50.55       4.48     34.22
# 77     [0.01, 0.01]         3.71       49.83       3.72     32.35
# 79           [0, 0]         3.68       44.48       3.68     29.61
# 83     [0.04, 0.04]         3.63       47.79       3.67     31.23
# 66     [0.03, 0.03]         3.60       51.71       3.63     33.10
# 94     [0.02, 0.02]         3.50       49.64       3.52     31.86
# 82     [0.04, 0.04]         3.42       47.12       3.46     30.48
# 81     [0.44, 0.44]         2.46       51.00       2.90     30.98
# 91     [0.01, 0.01]         2.41       47.95       2.42     28.83
# 90           [0, 0]         2.40       55.38       2.40     32.50
# 97     [0.01, 0.01]         2.22       45.00       2.23     26.95
# 88     [0.01, 0.01]         2.18       47.45       2.19     28.11
# 99     [0.01, 0.01]         1.99       52.46       2.00     30.24
# 86           [0, 0]         1.96        0.00       1.96     31.59
# 117    [0.02, 0.02]         1.83        0.00       1.85     27.86
# 103    [0.01, 0.01]         1.56        0.00       1.57     31.49
# 110    [0.01, 0.01]         1.25        0.00       1.26     30.96
# 102          [0, 0]         1.08        0.00       1.08     28.87
# 100    [0.01, 0.01]         0.94        0.00       0.95     27.88
# 124    [0.02, 0.02]         0.93        0.00       0.95     24.27
#
#      allBrandRate  allMvpRate  avgNewScore  assistCnt  deadCnt  totalPrice  \
# 13          19.25       16.32         2077       4.25     2.99        9456
# 18          34.59       28.18         2080       4.32     2.58       10824
# 19          20.73       28.10         2066       4.54     3.01       10343
# 11          32.68       25.77         2072       4.19     2.79       10526
# 29          26.67       23.23         2072       4.36     2.65       10762
# 31          20.01       23.86         2073       3.68     2.99       10238
# 14          19.94       16.15         2069       4.28     3.44       10163
# 27          19.67       17.96         2056       4.48     2.71        9718
# 6           35.76       35.52         2081       4.69     2.60       10771
# 42          18.16       14.85         2069       4.18     3.24       10441
# 45          22.01       24.82         2073       5.01     2.55        9798
# 43          27.19       22.80         2082       4.30     2.76       10684
# 52          21.50       18.18         2069       4.36     2.83       10214
# 67          27.75       24.16         2094       4.28     3.09        9907
# 57          17.22       21.07         2083       4.29     3.39       10260
# 75          28.23       25.12         2075       4.18     3.17       10001
# 72          18.27       19.84         2071       5.15     2.99        9988
# 71          20.05       19.50         2085       4.08     2.60       10620
# 69          25.55       27.77         2062       4.07     3.28        9933
# 77          21.92       21.59         2064       3.97     3.25       10720
# 79          21.07       18.39         2061       4.63     2.71       10161
# 83          17.62       15.93         2058       3.54     3.44       10394
# 66          11.64       15.41         2067       4.41     4.51       10417
# 94          17.25       11.61         2077       4.66     3.55        9366
# 82          23.02       20.14         2063       3.97     3.65       10348
# 81          19.00       15.00         2090       4.16     3.20        9766
# 91          18.87       19.89         2058       5.39     2.88       10086
# 90          25.64       22.56         2060       5.21     3.07       10341
# 97          17.77       15.00         2056       4.33     2.86        9958
# 88          16.94       11.86         2075       4.47     2.44        8937
# 99          24.69        8.64         2044       4.93     2.69        9045
# 86          18.23       13.20         2068       4.93     2.81       10328
# 117         26.84       13.42         2069       6.41     3.34        8343
# 103         26.77       19.68         2060       3.46     3.06        9500
# 110         24.50       12.74         2061       5.27     2.35       10269
# 102         20.45       18.18         2050       3.80     3.04       10591
# 100         18.18       22.07         2037       3.81     2.75       10235
# 124         18.42        7.89         2060       6.05     3.17        9088
#
#      totalPriceMin  evaluateGoldRate  evaluateSilverRate gradient   id  \
# 13             673              3.92               15.33     None  178
# 18             782              9.30               25.29     None  518
# 19             749              4.15               16.57     None  190
# 11             772              6.21               26.47     None  502
# 29             782              5.67               20.99     None  150
# 31             747              4.23               15.78     None  542
# 14             730              3.58               16.35     None  130
# 27             706              3.85               15.82     None  193
# 6              769              9.48               26.27     None  531
# 42             779              4.24               13.92     None  195
# 45             736              4.48               17.53     None  533
# 43             774              6.14               21.05     None  146
# 52             753              5.32               16.18     None  163
# 67             721              6.93               20.81     None  558
# 57             749              3.34               13.88     None  137
# 75             743              5.95               22.27     None  517
# 72             712              4.69               13.57     None  538
# 71             757              3.84               16.20     None  522
# 69             742              7.22               18.33     None  129
# 77             759              3.32               18.60     None  162
# 79             730              4.68               16.38     None  131
# 83             753              1.35               16.27     None  528
# 66             737              2.05                9.58     None  183
# 94             657              2.81               14.43     None  180
# 82             751              5.03               17.98     None  167
# 81             712              6.00               13.00     None  529
# 91             734              4.08               14.79     None  173
# 90             731              5.12               20.51     None  153
# 97             729              3.33               14.44     None  107
# 88             672              3.38               13.55     None  198
# 99             665              3.70               20.98     None  511
# 86             771              1.25               16.98     None  506
# 117            585              8.05               18.79     None  581
# 103            714             12.59               14.17     None  121
# 110            695              5.88               18.62     None  117
# 102            743              0.00               20.45     None  116
# 100            751              2.59               15.58     None  170
# 124            617              2.63               15.78     None  126
#
#                                                    img  joinGamePercent  \
# 13   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            54.63
# 18   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            56.85
# 19   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            61.97
# 11   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            61.77
# 29   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            58.21
# 31   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            63.81
# 14   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            58.67
# 27   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            57.91
# 6    //game.gtimg.cn/images/yxzj/img201606/heroimg/...            62.21
# 42   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            59.55
# 45   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            63.10
# 43   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            56.03
# 52   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            57.60
# 67   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            52.20
# 57   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            64.36
# 75   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            59.28
# 72   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            61.75
# 71   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            56.15
# 69   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            58.64
# 77   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            60.31
# 79   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            58.26
# 83   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            55.43
# 66   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            59.21
# 94   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            57.00
# 82   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            56.91
# 81   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            55.19
# 91   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            63.43
# 90   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            64.86
# 97   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            57.31
# 88   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            51.60
# 99   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            53.08
# 86   //game.gtimg.cn/images/yxzj/img201606/heroimg/...            62.01
# 117  //game.gtimg.cn/images/yxzj/img201606/heroimg/...            58.56
# 103  //game.gtimg.cn/images/yxzj/img201606/heroimg/...            47.22
# 110  //game.gtimg.cn/images/yxzj/img201606/heroimg/...            53.91
# 102  //game.gtimg.cn/images/yxzj/img201606/heroimg/...            56.60
# 100  //game.gtimg.cn/images/yxzj/img201606/heroimg/...            55.18
# 124  //game.gtimg.cn/images/yxzj/img201606/heroimg/...            53.50
#
#      killCnt  loseMvpRate     name                           cName  \
# 13      3.63         7.79       杨戬                      二郎神|哮天犬|yj
# 18      4.03        13.25       马超         神威|马子|马车|插秧|插秧王|电光马子|mc
# 19      4.32        13.42      诸葛亮                          村夫|zgl
# 11      4.33        11.18      裴擒虎             老虎|小虎|虎子|脑虎|李小龙|pqh
# 29      3.74         8.26       韩信                           猫雷|hx
# 31      5.29        10.49        暃                               菲
# 14      4.04         6.58     宫本武藏                   宫本|武藏|剑圣|gbwz
# 27      3.62         6.95        铠         肉铠|肉凯|恺爹|凯爹|铠爹|凯皇|铠皇|砍王
# 6       4.51        17.39        镜                      蝶|匿蝶|镜姐|镜神
# 42      4.52         4.90     百里玄策                     小疯子|玄策|blxc
# 45      3.92        11.64      阿古朵                      球球|阿骨朵|agd
# 43      3.80         8.33       露娜                        露辣|紫霞|ln
# 52      3.77         5.76      橘右京                       橘子|橘桑|jyj
# 67      3.37        11.00        影                            None
# 57      5.05         8.99      司马懿                          司马|smy
# 75      4.23        11.13      大司命                             dsm
# 72      3.67         9.66       云缨                           云嘤|yy
# 71      3.92         8.51        曜                          仙剑|李逍遥
# 69      4.40        11.66       典韦                阿韦|啊韦|疯狗|彻底疯狂|dw
# 77      5.34         8.63     娜可露露      小鸟|那可|娜可|露露|马马哈哈|玛玛哈哈|nkll
# 79      3.34         7.02       李白                       凤求凰|诗仙|lb
# 83      4.63         5.08        澜                           鲨鱼|吕蒙
# 66      4.63         8.21      雅典娜                             ydn
# 94      3.78         5.98       哪吒                 娜扎|挪扎|那托|三太子|nz
# 82      4.80         8.27      孙悟空  猴|猴子|猴哥|悟空|吉吉|猴三棒|大师兄|吉吉国王|swk
# 81      4.10         6.00       盘古                              pg
# 91      3.56         8.16      李元芳                          耗子|lyf
# 90      5.17         9.23      兰陵王                 兰陵灯|绿陵王|蓝零亡|llw
# 97      3.73         7.22       赵云                  赵六|宝马|龙胆|子龙|zy
# 88      1.85         5.64       梦奇                  肥猫|胖猫|胖达|荣荣|mq
# 99      2.56         3.70      猪八戒                八戒|猪头|悟能|二师兄|zbj
# 86      4.34         3.77      云中君                  小鸡|云中鸡|走地鸡|yzj
# 117     2.49         4.69  元流之子_坦克               坦元|元坦|源流|元流之子\_坦克
# 103     3.04         3.14       芈月                        闵月|太后|my
# 110     3.14         6.86      钟无艳                      锤子|锤子妈|zwy
# 102     4.96         4.54       阿轲                           荆轲|ak
# 100     4.05         7.79       刘备                       皇叔|刘皇叔|lb
# 124     2.01         3.94      夏侯惇                   夏侯|高达|吓猴蹲|xhd
#
#                                                  skill  tag  hurtTransRate  \
# 13   [{'id': 80115, 'img': '//camp.qq.com/images/sk...   []           1.00
# 18   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.87
# 19   [{'id': 80117, 'img': '//camp.qq.com/images/sk...   []           1.18
# 11   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.84
# 29   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.78
# 31   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.92
# 14   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.76
# 27   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.88
# 6    [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.88
# 42   [{'id': 80104, 'img': '//camp.qq.com/images/sk...  NaN           0.70
# 45   [{'id': 80104, 'img': '//camp.qq.com/images/sk...  NaN           1.06
# 43   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.88
# 52   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.88
# 67   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           1.06
# 57   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.88
# 75   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           1.05
# 72   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.98
# 71   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.84
# 69   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.95
# 77   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.86
# 79   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.93
# 83   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.77
# 66   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.92
# 94   [{'id': 80108, 'img': '//camp.qq.com/images/sk...   []           0.91
# 82   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.75
# 81   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.94
# 91   [{'id': 80115, 'img': '//camp.qq.com/images/sk...   []           0.97
# 90   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.76
# 97   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.81
# 88   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.82
# 99   [{'id': 80108, 'img': '//camp.qq.com/images/sk...   []           0.80
# 86   [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.76
# 117  [{'id': 80104, 'img': '//camp.qq.com/images/sk...  NaN           0.84
# 103  [{'id': 80110, 'img': '//camp.qq.com/images/sk...   []           0.95
# 110  [{'id': 80115, 'img': '//camp.qq.com/images/sk...   []           0.85
# 102  [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.74
# 100  [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.90
# 124  [{'id': 80104, 'img': '//camp.qq.com/images/sk...   []           0.82
#
#      totalHurtCnt  totalHeroHurtCnt  totalBeHurtCnt  beHurtPerDeath  trend  \
# 13         348884             70567           94278           30496      2
# 18         493978             69551           84969           30482      0
# 19         450016             91536           68839           21710      1
# 11         529756             63020           79405           26092      0
# 29         551251             60795           74991           24719      2
# 31         499214             69775           72626           22036      2
# 14         483597             56903           82456           21330      1
# 27         470868             64713           82502           27494      1
# 6          537070             72026           81493           27974      2
# 42         537672             50622           64133           19067      0
# 45         424573             77423          119636           45305      2
# 43         587585             69447           95633           30225      1
# 52         512272             65301           75952           24998      0
# 67         361809             79399          112983           38351      0
# 57         485700             65437           81542           20979      1
# 75         510276             80182           88764           26908      0
# 72         480539             73650           81410           25771      0
# 71         524870             67600           80717           29049      0
# 69         523309             70418           83810           23407      1
# 77         547149             68026           68936           19298      0
# 79         502163             70527           61501           19952      0
# 83         508761             57813           82268           22058      1
# 66         516640             71172          102476           20519      0
# 94         304916             65018          103711           26851      0
# 82         558366             58069           84796           21305      1
# 81         476045             68482           82298           23525      0
# 91         462481             73425           65486           23241      0
# 90         463716             58712           60212           17489      2
# 97         483286             57773           86683           29228      0
# 88         343706             55570          100584           39795      0
# 99         293032             52294          142284           52737      0
# 86         506746             56570           73799           22794      2
# 117        225459             52418          133967           43325      0
# 103        403708             65788           82311           24545      0
# 110        395939             66483          107884           41990      2
# 102        552874             56968           75503           23436      0
# 100        516380             68502           91772           31625      0
# 124        311966             57080          157258           49480      0
#
#           type   updateId  usedtime  winMvpRate  change.updateType  \
# 13   [1, 4, 0]  233695316     14.04        8.52                  0
# 18   [4, 1, 0]  358740390     13.82       14.93                  1
# 19   [2, 4, 0]  233695495     13.80       14.68                  0
# 11   [4, 0, 0]  266543930     13.62       14.59                  0
# 29   [4, 0, 0]  233691612     13.75       14.97                  0
# 31   [4, 0, 0]  579741263     13.68       13.37                  0
# 14   [4, 0, 0]  233692342     13.91        9.57                  1
# 27   [4, 0, 0]  235223355     13.74       11.01                  1
# 6    [4, 0, 0]  410599397     14.00       18.12                  0
# 42   [4, 0, 0]  240425183     13.38        9.94                  0
# 45   [4, 3, 0]  442136325     13.30       13.18                  2
# 43   [4, 0, 0]  233692100     13.78       14.47                  1
# 52   [4, 0, 0]  233695170     13.55       12.41                  0
# 67   [1, 4, 0]      12345     13.73       13.15                  0
# 57   [4, 0, 0]  296832796     13.69       12.08                  0
# 75   [4, 0, 0]      12345     13.45       13.98                  2
# 72   [4, 0, 0]  527555951     14.02       10.18                  0
# 71   [4, 0, 0]  350791555     14.01       10.98                  0
# 69   [4, 0, 0]  233690900     13.37       16.11                  0
# 77   [4, 0, 0]  233693725     14.11       12.95                  0
# 79   [4, 0, 0]  233693817     13.91       11.37                  0
# 83   [4, 0, 0]  474705708     13.79       10.84                  0
# 66   [4, 0, 0]  233695037     14.12        7.19                  0
# 94   [1, 4, 0]  233695436     14.24        5.63                  2
# 82   [4, 0, 0]  233692737     13.77       11.87                  0
# 81   [4, 0, 0]  324272317     13.70        9.00                  0
# 91   [3, 4, 0]  233693951     13.74       11.73                  0
# 90   [4, 0, 0]  233693631     14.14       13.33                  2
# 97   [4, 0, 0]  233691459     13.64        7.77                  0
# 88   [1, 4, 0]  248509092     13.29        6.21                  0
# 99   [1, 4, 0]  320050548     13.59        4.93                  0
# 86   [4, 0, 0]  339663393     13.39        9.43                  0
# 117  [4, 5, 1]      12345     14.24        8.72                  0
# 103  [1, 4, 0]  233692926     13.29       16.53                  0
# 110  [1, 4, 0]  233690349     14.77        5.88                  0
# 102  [4, 0, 0]  233691265     14.23       13.63                  0
# 100  [4, 0, 0]  233693506     13.61       14.28                  0
# 124  [4, 1, 0]  233694724     14.72        3.94                  0
#
#      change.updateValue          tag.color tag.text
# 13                 0.00                NaN      NaN
# 18                 2.38                NaN      NaN
# 19                 0.00                NaN      NaN
# 11                 0.00                NaN      NaN
# 29                 0.00                NaN      NaN
# 31                 0.00                NaN      NaN
# 14                 1.16                NaN      NaN
# 27                 1.03                NaN      NaN
# 6                  0.00                NaN      NaN
# 42                 0.00             orange     闷声发财
# 45                -1.23             orange     闷声发财
# 43                 1.34                NaN      NaN
# 52                 0.00                NaN      NaN
# 67                 0.00                NaN      NaN
# 57                 0.00                NaN      NaN
# 75                -1.08                NaN      NaN
# 72                 0.00                NaN      NaN
# 71                 0.00                NaN      NaN
# 69                 0.00                NaN      NaN
# 77                 0.00                NaN      NaN
# 79                 0.00                NaN      NaN
# 83                 0.00                NaN      NaN
# 66                 0.00                NaN      NaN
# 94                -1.11                NaN      NaN
# 82                 0.00                NaN      NaN
# 81                 0.00                NaN      NaN
# 91                 0.00                NaN      NaN
# 90                -1.04                NaN      NaN
# 97                 0.00                NaN      NaN
# 88                 0.00                NaN      NaN
# 99                 0.00                NaN      NaN
# 86                 0.00                NaN      NaN
# 117                0.00  rgb(35, 124, 123)       元坦
# 103                0.00                NaN      NaN
# 110                0.00                NaN      NaN
# 102                0.00                NaN      NaN
# 100                0.00                NaN      NaN
# 124                0.00                NaN      NaN

# %%
test_url2 = "https://api.91m.top/hero/app?type=getRanking&aid=0&bid=0&cid=1&did=0&host=91m.top&lang=zh-CN&ref=&game_type=wzry&url=https%3A%2F%2F91m.top%2Franking%3Ftype%3D0%26bid%3D0%26cid%3D1%26did%3D0%26eid%3Db%26refresh%3D1&url_real=https%3A%2F%2F91m.top%2Franking%3Ftype%3D0%26bid%3D0%26cid%3D1%26did%3D0%26eid%3Db%26refresh%3D1&ts=1740647566&sign=d8a93b36c52d801cf197f549aa81d012"

cookies = {
        'openId': '1c603c87200cd0b71b12a9936d28b16c',
        'accessToken': 'da310cec06960e4738d0a02f49d9a0d9'}

# %%
response2 = requests.get(test_url2, cookies=cookies)

# %%
response2
# Out:
# <Response [200]>

# %%
data_res2 = json.loads(response2.text)

# %%
data_res2
# Out:
# {'data': {'result': {'color': {'bp': 70, 'ban': 30, 'pick': 20, 'win': 50},
#    'whiteList': True,
#    'rows': [{'allBanRate': [60.94, 52.02],
#      'allPickRate': 33.62,
#      'allWinRate': 51.87,
#      'allBPRate': 85.64,
#      'allScore': 158.2,
#      'allBrandRate': 20.68,
#      'allMvpRate': 16.63,
#      'avgNewScore': 2089,
#      'assistCnt': 4.73,
#      'deadCnt': 2.88,
#      'totalPrice': 9326,
#      'totalPriceMin': 688,
#      'evaluateGoldRate': 4.67,
#      'evaluateSilverRate': 16.01,
#      'gradient': None,
#      'id': 128,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/128/128.jpg',
#      'joinGamePercent': 53.34,
#      'killCnt': 2.88,
#      'loseMvpRate': 7.29,
#      'name': '曹操',
#      'cName': '曹尺|曹三磕|曹老板|cc',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 92},
#       {'id': 1137,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1137.jpg',
#        'pickRate': 98}],
#      'tag': [],
#      'hurtTransRate': 0.99,
#      'totalHurtCnt': 308182,
#      'totalHeroHurtCnt': 68446,
#      'totalBeHurtCnt': 94391,
#      'beHurtPerDeath': 32671,
#      'trend': 2,
#      'type': [1, 0, 0],
#      'updateId': 233692400,
#      'usedtime': 13.55,
#      'winMvpRate': 9.34,
#      'change': {'updateType': 1, 'updateValue': 2.21}},
#     {'allBanRate': [26.73, 25.01],
#      'allPickRate': 24.31,
#      'allWinRate': 50.86,
#      'allBPRate': 49.32,
#      'allScore': 105.33,
#      'allBrandRate': 21.48,
#      'allMvpRate': 16.29,
#      'avgNewScore': 2081,
#      'assistCnt': 4.34,
#      'deadCnt': 2.92,
#      'totalPrice': 9386,
#      'totalPriceMin': 676,
#      'evaluateGoldRate': 4.27,
#      'evaluateSilverRate': 17.2,
#      'gradient': None,
#      'id': 178,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/178/178.jpg',
#      'joinGamePercent': 55.4,
#      'killCnt': 3.64,
#      'loseMvpRate': 7.32,
#      'name': '杨戬',
#      'cName': '二郎神|哮天犬|yj',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 52},
#       {'id': 1137,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1137.jpg',
#        'pickRate': 96}],
#      'tag': [],
#      'hurtTransRate': 1,
#      'totalHurtCnt': 346860,
#      'totalHeroHurtCnt': 69540,
#      'totalBeHurtCnt': 93225,
#      'beHurtPerDeath': 31617,
#      'trend': 2,
#      'type': [1, 4, 0],
#      'updateId': 233695316,
#      'usedtime': 13.86,
#      'winMvpRate': 8.97,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [10.17, 9.88],
#      'allPickRate': 27.51,
#      'allWinRate': 48.72,
#      'allBPRate': 37.39,
#      'allScore': 91.75,
#      'allBrandRate': 24.18,
#      'allMvpRate': 11.56,
#      'avgNewScore': 2081,
#      'assistCnt': 5.24,
#      'deadCnt': 2.83,
#      'totalPrice': 8485,
#      'totalPriceMin': 631,
#      'evaluateGoldRate': 6.14,
#      'evaluateSilverRate': 18.03,
#      'gradient': None,
#      'id': 503,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/503/503.jpg',
#      'joinGamePercent': 50.59,
#      'killCnt': 1.69,
#      'loseMvpRate': 6.65,
#      'name': '狂铁',
#      'cName': '狂贴|铁子|kt',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 99},
#       {'id': 11311,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimgo/11311.png',
#        'pickRate': 93}],
#      'tag': [],
#      'hurtTransRate': 0.87,
#      'totalHurtCnt': 231459,
#      'totalHeroHurtCnt': 53585,
#      'totalBeHurtCnt': 122522,
#      'beHurtPerDeath': 43545,
#      'trend': 2,
#      'type': [1, 0, 0],
#      'updateId': 272986391,
#      'usedtime': 13.43,
#      'winMvpRate': 4.9,
#      'change': {'updateType': 1, 'updateValue': 1.12}},
#     {'allBanRate': [4.98, 4.89],
#      'allPickRate': 24.63,
#      'allWinRate': 50.52,
#      'allBPRate': 29.52,
#      'allScore': 80.64,
#      'allBrandRate': 35.54,
#      'allMvpRate': 26.4,
#      'avgNewScore': 2093,
#      'assistCnt': 4.19,
#      'deadCnt': 2.62,
#      'totalPrice': 10535,
#      'totalPriceMin': 775,
#      'evaluateGoldRate': 8.93,
#      'evaluateSilverRate': 26.6,
#      'gradient': None,
#      'id': 518,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/518/518.jpg',
#      'joinGamePercent': 57.61,
#      'killCnt': 3.86,
#      'loseMvpRate': 10.8,
#      'name': '马超',
#      'cName': '神威|马子|马车|插秧|插秧王|电光马子|mc',
#      'skill': [{'id': 80104,
#        'img': '//camp.qq.com/images/skill/80104.png',
#        'pickRate': 52},
#       {'id': 1137,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1137.jpg',
#        'pickRate': 89}],
#      'tag': [],
#      'hurtTransRate': 0.87,
#      'totalHurtCnt': 469046,
#      'totalHeroHurtCnt': 66417,
#      'totalBeHurtCnt': 82325,
#      'beHurtPerDeath': 29372,
#      'trend': 0,
#      'type': [4, 1, 0],
#      'updateId': 358740390,
#      'usedtime': 13.58,
#      'winMvpRate': 15.59,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [8.06, 7.92],
#      'allPickRate': 14.48,
#      'allWinRate': 51.51,
#      'allBPRate': 22.4,
#      'allScore': 64.64,
#      'allBrandRate': 26.79,
#      'allMvpRate': 21.61,
#      'avgNewScore': 2071,
#      'assistCnt': 4.7,
#      'deadCnt': 2.26,
#      'totalPrice': 9317,
#      'totalPriceMin': 664,
#      'evaluateGoldRate': 5.52,
#      'evaluateSilverRate': 21.27,
#      'gradient': None,
#      'id': 125,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/125/125.jpg',
#      'joinGamePercent': 54,
#      'killCnt': 3.22,
#      'loseMvpRate': 11.74,
#      'name': '元歌',
#      'cName': '庞统|傀儡|甜筒|yg',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 91},
#       {'id': 1137,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1137.jpg',
#        'pickRate': 99}],
#      'tag': [],
#      'hurtTransRate': 1.03,
#      'totalHurtCnt': 267873,
#      'totalHeroHurtCnt': 71774,
#      'totalBeHurtCnt': 50184,
#      'beHurtPerDeath': 21570,
#      'trend': 1,
#      'type': [1, 0, 0],
#      'updateId': 284211343,
#      'usedtime': 14.02,
#      'winMvpRate': 9.87,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [2.91, 2.9],
#      'allPickRate': 13.6,
#      'allWinRate': 47.35,
#      'allBPRate': 16.5,
#      'allScore': 54.52,
#      'allBrandRate': 24.77,
#      'allMvpRate': 22.2,
#      'avgNewScore': 2103,
#      'assistCnt': 3.88,
#      'deadCnt': 3.19,
#      'totalPrice': 9271,
#      'totalPriceMin': 689,
#      'evaluateGoldRate': 6.83,
#      'evaluateSilverRate': 17.94,
#      'gradient': None,
#      'id': 172,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/172/172.jpg',
#      'joinGamePercent': 52.23,
#      'killCnt': 3.54,
#      'loseMvpRate': 10.58,
#      'name': '蚩奼',
#      'cName': '吃茶|媸姹|叱咤',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 70},
#       {'id': 1135,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1135.jpg',
#        'pickRate': 92}],
#      'tag': [],
#      'hurtTransRate': 1.03,
#      'totalHurtCnt': 323285,
#      'totalHeroHurtCnt': 70593,
#      'totalBeHurtCnt': 81168,
#      'beHurtPerDeath': 24500,
#      'trend': 2,
#      'type': [1, 0, 0],
#      'updateId': 12345,
#      'usedtime': 13.45,
#      'winMvpRate': 11.61,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [2.11, 2.1],
#      'allPickRate': 9.95,
#      'allWinRate': 54.57,
#      'allBPRate': 12.05,
#      'allScore': 49.82,
#      'allBrandRate': 24.92,
#      'allMvpRate': 12.26,
#      'avgNewScore': 2083,
#      'assistCnt': 5.14,
#      'deadCnt': 2.95,
#      'totalPrice': 8961,
#      'totalPriceMin': 643,
#      'evaluateGoldRate': 4.22,
#      'evaluateSilverRate': 20.7,
#      'gradient': None,
#      'id': 140,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/140/140.jpg',
#      'joinGamePercent': 53.59,
#      'killCnt': 2.97,
#      'loseMvpRate': 6.73,
#      'name': '关羽',
#      'cName': '二哥|武圣|冰封|冰峰|冰马|关二爷|gy',
#      'skill': [{'id': 80109,
#        'img': '//camp.qq.com/images/skill/80109.png',
#        'pickRate': 98},
#       {'id': 1341,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1341.jpg',
#        'pickRate': 78}],
#      'tag': {'color': 'orange', 'text': '闷声发财'},
#      'hurtTransRate': 0.76,
#      'totalHurtCnt': 232288,
#      'totalHeroHurtCnt': 48039,
#      'totalBeHurtCnt': 73873,
#      'beHurtPerDeath': 24238,
#      'trend': 1,
#      'type': [1, 0, 0],
#      'updateId': 233694489,
#      'usedtime': 13.92,
#      'winMvpRate': 5.52,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.37, 0.37],
#      'allPickRate': 12.86,
#      'allWinRate': 48.13,
#      'allBPRate': 13.22,
#      'allScore': 50.26,
#      'allBrandRate': 24.8,
#      'allMvpRate': 16.4,
#      'avgNewScore': 2094,
#      'assistCnt': 4.2,
#      'deadCnt': 3.19,
#      'totalPrice': 9230,
#      'totalPriceMin': 675,
#      'evaluateGoldRate': 6.76,
#      'evaluateSilverRate': 18.04,
#      'gradient': None,
#      'id': 536,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/536/536.jpg',
#      'joinGamePercent': 49.94,
#      'killCnt': 2.77,
#      'loseMvpRate': 8.78,
#      'name': '夏洛特',
#      'cName': 'xlt',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 98},
#       {'id': 1137,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1137.jpg',
#        'pickRate': 96}],
#      'tag': [],
#      'hurtTransRate': 0.96,
#      'totalHurtCnt': 309607,
#      'totalHeroHurtCnt': 65148,
#      'totalBeHurtCnt': 89858,
#      'beHurtPerDeath': 27726,
#      'trend': 0,
#      'type': [1, 0, 0],
#      'updateId': 454951873,
#      'usedtime': 13.66,
#      'winMvpRate': 7.62,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [2.53, 2.5],
#      'allPickRate': 10.07,
#      'allWinRate': 51.53,
#      'allBPRate': 12.57,
#      'allScore': 49.04,
#      'allBrandRate': 18.96,
#      'allMvpRate': 12.21,
#      'avgNewScore': 2083,
#      'assistCnt': 4.5,
#      'deadCnt': 3.03,
#      'totalPrice': 8618,
#      'totalPriceMin': 635,
#      'evaluateGoldRate': 3.17,
#      'evaluateSilverRate': 15.78,
#      'gradient': None,
#      'id': 527,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/527/527.jpg',
#      'joinGamePercent': 50.62,
#      'killCnt': 2.49,
#      'loseMvpRate': 6.55,
#      'name': '蒙恬',
#      'cName': '蒙田|mt',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 99},
#       {'id': 13310,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimgo/13310.png',
#        'pickRate': 81}],
#      'tag': {'color': 'orange', 'text': '闷声发财'},
#      'hurtTransRate': 1.01,
#      'totalHurtCnt': 244743,
#      'totalHeroHurtCnt': 62991,
#      'totalBeHurtCnt': 84676,
#      'beHurtPerDeath': 28281,
#      'trend': 1,
#      'type': [1, 0, 0],
#      'updateId': 426699497,
#      'usedtime': 13.55,
#      'winMvpRate': 5.66,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [1.53, 1.53],
#      'allPickRate': 11.23,
#      'allWinRate': 50.93,
#      'allBPRate': 12.76,
#      'allScore': 49.85,
#      'allBrandRate': 24.57,
#      'allMvpRate': 9.79,
#      'avgNewScore': 2089,
#      'assistCnt': 5.19,
#      'deadCnt': 3.24,
#      'totalPrice': 8611,
#      'totalPriceMin': 643,
#      'evaluateGoldRate': 7.12,
#      'evaluateSilverRate': 17.45,
#      'gradient': None,
#      'id': 139,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/139/139.jpg',
#      'joinGamePercent': 49.69,
#      'killCnt': 1.76,
#      'loseMvpRate': 5.34,
#      'name': '老夫子',
#      'cName': '老天子|lfz',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 95},
#       {'id': 1135,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1135.jpg',
#        'pickRate': 99}],
#      'tag': {'color': 'orange', 'text': '闷声发财'},
#      'hurtTransRate': 0.66,
#      'totalHurtCnt': 213976,
#      'totalHeroHurtCnt': 39770,
#      'totalBeHurtCnt': 66897,
#      'beHurtPerDeath': 19711,
#      'trend': 2,
#      'type': [1, 0, 0],
#      'updateId': 233690609,
#      'usedtime': 13.37,
#      'winMvpRate': 4.45,
#      'change': {'updateType': 2, 'updateValue': -1.22}},
#     {'allBanRate': [0.14, 0.14],
#      'allPickRate': 8.21,
#      'allWinRate': 44.82,
#      'allBPRate': 8.35,
#      'allScore': 39.01,
#      'allBrandRate': 26.91,
#      'allMvpRate': 17.53,
#      'avgNewScore': 2077,
#      'assistCnt': 4.2,
#      'deadCnt': 3.08,
#      'totalPrice': 9357,
#      'totalPriceMin': 695,
#      'evaluateGoldRate': 7.43,
#      'evaluateSilverRate': 19.48,
#      'gradient': None,
#      'id': 537,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/537/537.jpg',
#      'joinGamePercent': 51.87,
#      'killCnt': 2.54,
#      'loseMvpRate': 8.76,
#      'name': '司空震',
#      'cName': '拳王|雷电|雷霆|skz',
#      'skill': [{'id': 80110,
#        'img': '//camp.qq.com/images/skill/80110.png',
#        'pickRate': 50},
#       {'id': 1135,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1135.jpg',
#        'pickRate': 97}],
#      'tag': [],
#      'hurtTransRate': 0.96,
#      'totalHurtCnt': 313259,
#      'totalHeroHurtCnt': 66325,
#      'totalBeHurtCnt': 104682,
#      'beHurtPerDeath': 33648,
#      'trend': 1,
#      'type': [1, 3, 0],
#      'updateId': 485513224,
#      'usedtime': 13.45,
#      'winMvpRate': 8.76,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.02, 0.02],
#      'allPickRate': 5.26,
#      'allWinRate': 51.71,
#      'allBPRate': 5.27,
#      'allScore': 36.4,
#      'allBrandRate': 29.65,
#      'allMvpRate': 15.77,
#      'avgNewScore': 2056,
#      'assistCnt': 4.21,
#      'deadCnt': 3.22,
#      'totalPrice': 9482,
#      'totalPriceMin': 689,
#      'evaluateGoldRate': 6.46,
#      'evaluateSilverRate': 23.19,
#      'gradient': None,
#      'id': 154,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/154/154.jpg',
#      'joinGamePercent': 49.48,
#      'killCnt': 3.2,
#      'loseMvpRate': 8.93,
#      'name': '花木兰',
#      'cName': '瑞麟|hml',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 99},
#       {'id': 1137,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1137.jpg',
#        'pickRate': 99}],
#      'tag': [],
#      'hurtTransRate': 0.87,
#      'totalHurtCnt': 292906,
#      'totalHeroHurtCnt': 58990,
#      'totalBeHurtCnt': 59246,
#      'beHurtPerDeath': 18676,
#      'trend': 1,
#      'type': [1, 0, 0],
#      'updateId': 233693263,
#      'usedtime': 13.75,
#      'winMvpRate': 6.84,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.08, 0.08],
#      'allPickRate': 6.15,
#      'allWinRate': 46.66,
#      'allBPRate': 6.23,
#      'allScore': 35.74,
#      'allBrandRate': 18.69,
#      'allMvpRate': 11.7,
#      'avgNewScore': 2072,
#      'assistCnt': 3.9,
#      'deadCnt': 3.25,
#      'totalPrice': 9080,
#      'totalPriceMin': 651,
#      'evaluateGoldRate': 5.04,
#      'evaluateSilverRate': 13.65,
#      'gradient': None,
#      'id': 564,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/564/564.jpg',
#      'joinGamePercent': 48.62,
#      'killCnt': 3.41,
#      'loseMvpRate': 7.8,
#      'name': '姬小满',
#      'cName': '基小满|jxm',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 79},
#       {'id': 1137,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1137.jpg',
#        'pickRate': 99}],
#      'tag': [],
#      'hurtTransRate': 0.77,
#      'totalHurtCnt': 218195,
#      'totalHeroHurtCnt': 50313,
#      'totalBeHurtCnt': 78052,
#      'beHurtPerDeath': 24642,
#      'trend': 1,
#      'type': [1, 0, 0],
#      'updateId': 12345,
#      'usedtime': 13.93,
#      'winMvpRate': 3.9,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.03, 0.03],
#      'allPickRate': 4.39,
#      'allWinRate': 51.25,
#      'allBPRate': 4.42,
#      'allScore': 34.44,
#      'allBrandRate': 23.46,
#      'allMvpRate': 12.98,
#      'avgNewScore': 2082,
#      'assistCnt': 6.06,
#      'deadCnt': 3.77,
#      'totalPrice': 8766,
#      'totalPriceMin': 651,
#      'evaluateGoldRate': 5.69,
#      'evaluateSilverRate': 17.76,
#      'gradient': None,
#      'id': 510,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/510/510.jpg',
#      'joinGamePercent': 62.84,
#      'killCnt': 3.36,
#      'loseMvpRate': 6.6,
#      'name': '孙策',
#      'cName': '孙笨|船夫|sc',
#      'skill': [{'id': 80108,
#        'img': '//camp.qq.com/images/skill/80108.png',
#        'pickRate': 53},
#       {'id': 1422,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1422.jpg',
#        'pickRate': 71}],
#      'tag': [],
#      'hurtTransRate': 0.78,
#      'totalHurtCnt': 231617,
#      'totalHeroHurtCnt': 47811,
#      'totalBeHurtCnt': 76352,
#      'beHurtPerDeath': 20500,
#      'trend': 2,
#      'type': [1, 0, 0],
#      'updateId': 286315155,
#      'usedtime': 13.44,
#      'winMvpRate': 6.37,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.03, 0.03],
#      'allPickRate': 5.96,
#      'allWinRate': 46.81,
#      'allBPRate': 5.99,
#      'allScore': 35.37,
#      'allBrandRate': 20.97,
#      'allMvpRate': 17.78,
#      'avgNewScore': 2075,
#      'assistCnt': 3.9,
#      'deadCnt': 3.21,
#      'totalPrice': 9766,
#      'totalPriceMin': 706,
#      'evaluateGoldRate': 3.52,
#      'evaluateSilverRate': 17.44,
#      'gradient': None,
#      'id': 558,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/558/558.jpg',
#      'joinGamePercent': 51.17,
#      'killCnt': 3.1,
#      'loseMvpRate': 8.89,
#      'name': '影',
#      'cName': None,
#      'skill': [{'id': 80117,
#        'img': '//camp.qq.com/images/skill/80117.png',
#        'pickRate': 43},
#       {'id': 1422,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1422.jpg',
#        'pickRate': 45}],
#      'tag': [],
#      'hurtTransRate': 1.03,
#      'totalHurtCnt': 343693,
#      'totalHeroHurtCnt': 75271,
#      'totalBeHurtCnt': 109665,
#      'beHurtPerDeath': 35318,
#      'trend': 0,
#      'type': [1, 4, 0],
#      'updateId': 12345,
#      'usedtime': 13.83,
#      'winMvpRate': 8.89,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.01, 0.01],
#      'allPickRate': 2.32,
#      'allWinRate': 49.56,
#      'allBPRate': 2.32,
#      'allScore': 29.43,
#      'allBrandRate': 25.43,
#      'allMvpRate': 18.53,
#      'avgNewScore': 2080,
#      'assistCnt': 4.41,
#      'deadCnt': 2.23,
#      'totalPrice': 9340,
#      'totalPriceMin': 700,
#      'evaluateGoldRate': 5.17,
#      'evaluateSilverRate': 20.25,
#      'gradient': None,
#      'id': 198,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/198/198.jpg',
#      'joinGamePercent': 50.61,
#      'killCnt': 2.33,
#      'loseMvpRate': 7.32,
#      'name': '梦奇',
#      'cName': '肥猫|胖猫|胖达|荣荣|mq',
#      'skill': [{'id': 80104,
#        'img': '//camp.qq.com/images/skill/80104.png',
#        'pickRate': 59},
#       {'id': 1136,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1136.jpg',
#        'pickRate': 43}],
#      'tag': [],
#      'hurtTransRate': 0.86,
#      'totalHurtCnt': 373421,
#      'totalHeroHurtCnt': 58284,
#      'totalBeHurtCnt': 101430,
#      'beHurtPerDeath': 40727,
#      'trend': 0,
#      'type': [1, 4, 0],
#      'updateId': 248509092,
#      'usedtime': 13.33,
#      'winMvpRate': 11.2,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.06, 0.06],
#      'allPickRate': 2.19,
#      'allWinRate': 48.4,
#      'allBPRate': 2.25,
#      'allScore': 28.65,
#      'allBrandRate': 20.09,
#      'allMvpRate': 11.87,
#      'avgNewScore': 2038,
#      'assistCnt': 4.65,
#      'deadCnt': 2.89,
#      'totalPrice': 8775,
#      'totalPriceMin': 643,
#      'evaluateGoldRate': 7.3,
#      'evaluateSilverRate': 12.78,
#      'gradient': None,
#      'id': 120,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/120/120.jpg',
#      'joinGamePercent': 53.27,
#      'killCnt': 3.03,
#      'loseMvpRate': 6.39,
#      'name': '白起',
#      'cName': '电风扇|bq',
#      'skill': [{'id': 80108,
#        'img': '//camp.qq.com/images/skill/80108.png',
#        'pickRate': 68},
#       {'id': 1534,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1534.jpg',
#        'pickRate': 58}],
#      'tag': [],
#      'hurtTransRate': 0.71,
#      'totalHurtCnt': 208115,
#      'totalHeroHurtCnt': 43716,
#      'totalBeHurtCnt': 123589,
#      'beHurtPerDeath': 43831,
#      'trend': 0,
#      'type': [1, 0, 0],
#      'updateId': 233691071,
#      'usedtime': 13.64,
#      'winMvpRate': 5.47,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.06, 0.06],
#      'allPickRate': 2.75,
#      'allWinRate': 49.09,
#      'allBPRate': 2.81,
#      'allScore': 30.12,
#      'allBrandRate': 23.27,
#      'allMvpRate': 10.9,
#      'avgNewScore': 2060,
#      'assistCnt': 6.81,
#      'deadCnt': 3.11,
#      'totalPrice': 7913,
#      'totalPriceMin': 563,
#      'evaluateGoldRate': 6.18,
#      'evaluateSilverRate': 17.09,
#      'gradient': None,
#      'id': 544,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/544/544.jpg',
#      'joinGamePercent': 62.67,
#      'killCnt': 2.31,
#      'loseMvpRate': 3.27,
#      'name': '赵怀真',
#      'cName': '赵怀镇|接化发|太极|zhz',
#      'skill': [{'id': 80103,
#        'img': '//camp.qq.com/images/skill/80103.png',
#        'pickRate': 46},
#       {'id': 1347,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1347.jpg',
#        'pickRate': 13}],
#      'tag': [],
#      'hurtTransRate': 0.76,
#      'totalHurtCnt': 142832,
#      'totalHeroHurtCnt': 43639,
#      'totalBeHurtCnt': 108677,
#      'beHurtPerDeath': 37420,
#      'trend': 0,
#      'type': [5, 1, 0],
#      'updateId': 12345,
#      'usedtime': 14.04,
#      'winMvpRate': 7.63,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.02, 0.02],
#      'allPickRate': 2.41,
#      'allWinRate': 50.62,
#      'allBPRate': 2.43,
#      'allScore': 30.15,
#      'allBrandRate': 21.57,
#      'allMvpRate': 19.91,
#      'avgNewScore': 2070,
#      'assistCnt': 4.31,
#      'deadCnt': 3.6,
#      'totalPrice': 9337,
#      'totalPriceMin': 661,
#      'evaluateGoldRate': 4.56,
#      'evaluateSilverRate': 17.01,
#      'gradient': None,
#      'id': 180,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/180/180.jpg',
#      'joinGamePercent': 57.17,
#      'killCnt': 4.27,
#      'loseMvpRate': 10.37,
#      'name': '哪吒',
#      'cName': '娜扎|挪扎|那托|三太子|nz',
#      'skill': [{'id': 80108,
#        'img': '//camp.qq.com/images/skill/80108.png',
#        'pickRate': 63},
#       {'id': 1533,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1533.jpg',
#        'pickRate': 24}],
#      'tag': [],
#      'hurtTransRate': 0.96,
#      'totalHurtCnt': 301682,
#      'totalHeroHurtCnt': 65408,
#      'totalBeHurtCnt': 101537,
#      'beHurtPerDeath': 25702,
#      'trend': 0,
#      'type': [1, 4, 0],
#      'updateId': 233695436,
#      'usedtime': 14.11,
#      'winMvpRate': 9.54,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.02, 0.02],
#      'allPickRate': 2.64,
#      'allWinRate': 46.21,
#      'allBPRate': 2.66,
#      'allScore': 28.41,
#      'allBrandRate': 20.45,
#      'allMvpRate': 9.84,
#      'avgNewScore': 2053,
#      'assistCnt': 4.8,
#      'deadCnt': 3.3,
#      'totalPrice': 8859,
#      'totalPriceMin': 640,
#      'evaluateGoldRate': 3.78,
#      'evaluateSilverRate': 16.66,
#      'gradient': None,
#      'id': 134,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/134/134.jpg',
#      'joinGamePercent': 50.5,
#      'killCnt': 2.63,
#      'loseMvpRate': 5.3,
#      'name': '达摩',
#      'cName': '光头|dm',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 100},
#       {'id': 1422,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1422.jpg',
#        'pickRate': 73}],
#      'tag': [],
#      'hurtTransRate': 0.77,
#      'totalHurtCnt': 218339,
#      'totalHeroHurtCnt': 47946,
#      'totalBeHurtCnt': 73351,
#      'beHurtPerDeath': 22269,
#      'trend': 0,
#      'type': [1, 0, 0],
#      'updateId': 233691958,
#      'usedtime': 13.84,
#      'winMvpRate': 4.54,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.02, 0.02],
#      'allPickRate': 1.55,
#      'allWinRate': '--',
#      'allBPRate': 1.57,
#      'allScore': 25.7,
#      'allBrandRate': 28.38,
#      'allMvpRate': 14.83,
#      'avgNewScore': 2057,
#      'assistCnt': 4.52,
#      'deadCnt': 2.67,
#      'totalPrice': 9533,
#      'totalPriceMin': 661,
#      'evaluateGoldRate': 4.51,
#      'evaluateSilverRate': 23.87,
#      'gradient': None,
#      'id': 511,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/511/511.jpg',
#      'joinGamePercent': 52.21,
#      'killCnt': 2.63,
#      'loseMvpRate': 9.03,
#      'name': '猪八戒',
#      'cName': '八戒|猪头|悟能|二师兄|zbj',
#      'skill': [{'id': 80104,
#        'img': '//camp.qq.com/images/skill/80104.png',
#        'pickRate': 43},
#       {'id': 1532,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1532.jpg',
#        'pickRate': 38}],
#      'tag': [],
#      'hurtTransRate': 0.79,
#      'totalHurtCnt': 340967,
#      'totalHeroHurtCnt': 57142,
#      'totalBeHurtCnt': 154338,
#      'beHurtPerDeath': 59580,
#      'trend': 0,
#      'type': [4, 1, 0],
#      'updateId': 320050548,
#      'usedtime': 14.41,
#      'winMvpRate': 5.8,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0, 0],
#      'allPickRate': 1.09,
#      'allWinRate': '--',
#      'allBPRate': 1.09,
#      'allScore': 24.19,
#      'allBrandRate': 30.27,
#      'allMvpRate': 22.93,
#      'avgNewScore': 2062,
#      'assistCnt': 3.29,
#      'deadCnt': 3.33,
#      'totalPrice': 9486,
#      'totalPriceMin': 703,
#      'evaluateGoldRate': 4.58,
#      'evaluateSilverRate': 25.68,
#      'gradient': None,
#      'id': 121,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/121/121.jpg',
#      'joinGamePercent': 44.61,
#      'killCnt': 2.9,
#      'loseMvpRate': 11.92,
#      'name': '芈月',
#      'cName': '闵月|太后|my',
#      'skill': [{'id': 80110,
#        'img': '//camp.qq.com/images/skill/80110.png',
#        'pickRate': 69},
#       {'id': 1237,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1237.jpg',
#        'pickRate': 15}],
#      'tag': [],
#      'hurtTransRate': 0.96,
#      'totalHurtCnt': 405030,
#      'totalHeroHurtCnt': 66801,
#      'totalBeHurtCnt': 86169,
#      'beHurtPerDeath': 25859,
#      'trend': 0,
#      'type': [1, 4, 0],
#      'updateId': 233692926,
#      'usedtime': 13.49,
#      'winMvpRate': 11,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0, 0],
#      'allPickRate': 1.78,
#      'allWinRate': '--',
#      'allBPRate': 1.78,
#      'allScore': 28.56,
#      'allBrandRate': 23.03,
#      'allMvpRate': 16.29,
#      'avgNewScore': 2049,
#      'assistCnt': 3.6,
#      'deadCnt': 2.94,
#      'totalPrice': 8576,
#      'totalPriceMin': 639,
#      'evaluateGoldRate': 5.05,
#      'evaluateSilverRate': 17.97,
#      'gradient': None,
#      'id': 514,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/514/514.jpg',
#      'joinGamePercent': 51.56,
#      'killCnt': 3.82,
#      'loseMvpRate': 6.17,
#      'name': '亚连',
#      'cName': '娅连|yl',
#      'skill': [{'id': 80108,
#        'img': '//camp.qq.com/images/skill/80108.png',
#        'pickRate': 93},
#       {'id': 1421,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1421.jpg',
#        'pickRate': 48}],
#      'tag': [],
#      'hurtTransRate': 0.89,
#      'totalHurtCnt': 201966,
#      'totalHeroHurtCnt': 57327,
#      'totalBeHurtCnt': 81779,
#      'beHurtPerDeath': 27502,
#      'trend': 0,
#      'type': [1, 0, 0],
#      'updateId': 12345,
#      'usedtime': 13.4,
#      'winMvpRate': 10.11,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.11, 0.11],
#      'allPickRate': 2.74,
#      'allWinRate': 45.62,
#      'allBPRate': 2.85,
#      'allScore': 28.43,
#      'allBrandRate': 21.53,
#      'allMvpRate': 10.21,
#      'avgNewScore': 2040,
#      'assistCnt': 5.03,
#      'deadCnt': 3.28,
#      'totalPrice': 8421,
#      'totalPriceMin': 608,
#      'evaluateGoldRate': 4.01,
#      'evaluateSilverRate': 17.51,
#      'gradient': None,
#      'id': 123,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/123/123.jpg',
#      'joinGamePercent': 52.08,
#      'killCnt': 2.71,
#      'loseMvpRate': 5.83,
#      'name': '吕布',
#      'cName': '布学|绿布|卢布|奉先|lb',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 97},
#       {'id': 1421,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1421.jpg',
#        'pickRate': 19}],
#      'tag': [],
#      'hurtTransRate': 0.98,
#      'totalHurtCnt': 211313,
#      'totalHeroHurtCnt': 62025,
#      'totalBeHurtCnt': 89369,
#      'beHurtPerDeath': 26978,
#      'trend': 0,
#      'type': [1, 0, 0],
#      'updateId': 233693126,
#      'usedtime': 13.83,
#      'winMvpRate': 4.37,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.02, 0.02],
#      'allPickRate': 0.73,
#      'allWinRate': '--',
#      'allBPRate': 0.75,
#      'allScore': 29.56,
#      'allBrandRate': 21.91,
#      'allMvpRate': 10.95,
#      'avgNewScore': 2050,
#      'assistCnt': 5.23,
#      'deadCnt': 2.57,
#      'totalPrice': 10046,
#      'totalPriceMin': 688,
#      'evaluateGoldRate': 8.21,
#      'evaluateSilverRate': 13.69,
#      'gradient': None,
#      'id': 117,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/117/117.jpg',
#      'joinGamePercent': 51.24,
#      'killCnt': 3.01,
#      'loseMvpRate': 4.1,
#      'name': '钟无艳',
#      'cName': '锤子|锤子妈|zwy',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 57},
#       {'id': 1534,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1534.jpg',
#        'pickRate': 50}],
#      'tag': [],
#      'hurtTransRate': 0.87,
#      'totalHurtCnt': 399531,
#      'totalHeroHurtCnt': 64696,
#      'totalBeHurtCnt': 107806,
#      'beHurtPerDeath': 42288,
#      'trend': 0,
#      'type': [1, 4, 0],
#      'updateId': 233690349,
#      'usedtime': 14.6,
#      'winMvpRate': 6.84,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.02, 0.02],
#      'allPickRate': 1.26,
#      'allWinRate': '--',
#      'allBPRate': 1.28,
#      'allScore': 26.35,
#      'allBrandRate': 18.25,
#      'allMvpRate': 9.52,
#      'avgNewScore': 2050,
#      'assistCnt': 5.3,
#      'deadCnt': 3.3,
#      'totalPrice': 8008,
#      'totalPriceMin': 587,
#      'evaluateGoldRate': 5.55,
#      'evaluateSilverRate': 12.69,
#      'gradient': None,
#      'id': 135,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/135/135.jpg',
#      'joinGamePercent': 53.57,
#      'killCnt': 2.23,
#      'loseMvpRate': 3.96,
#      'name': '项羽',
#      'cName': '西楚|霸王|xy',
#      'skill': [{'id': 80115,
#        'img': '//camp.qq.com/images/skill/80115.png',
#        'pickRate': 68},
#       {'id': 1341,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1341.jpg',
#        'pickRate': 53}],
#      'tag': [],
#      'hurtTransRate': 0.85,
#      'totalHurtCnt': 165442,
#      'totalHeroHurtCnt': 50687,
#      'totalBeHurtCnt': 88254,
#      'beHurtPerDeath': 27912,
#      'trend': 0,
#      'type': [1, 5, 0],
#      'updateId': 233689508,
#      'usedtime': 13.62,
#      'winMvpRate': 5.55,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.04, 0.04],
#      'allPickRate': 1.47,
#      'allWinRate': '--',
#      'allBPRate': 1.51,
#      'allScore': 27.48,
#      'allBrandRate': 25.85,
#      'allMvpRate': 14.96,
#      'avgNewScore': 2079,
#      'assistCnt': 5.74,
#      'deadCnt': 2.97,
#      'totalPrice': 8210,
#      'totalPriceMin': 599,
#      'evaluateGoldRate': 6.8,
#      'evaluateSilverRate': 19.04,
#      'gradient': None,
#      'id': 581,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/581/581.jpg',
#      'joinGamePercent': 60.63,
#      'killCnt': 2.53,
#      'loseMvpRate': 6.8,
#      'name': '元流之子_坦克',
#      'cName': '坦元|元坦|源流|元流之子\\_坦克',
#      'skill': [{'id': 80104,
#        'img': '//camp.qq.com/images/skill/80104.png',
#        'pickRate': 46},
#       {'id': 1341,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1341.jpg',
#        'pickRate': 37}],
#      'tag': {'color': 'rgb(35, 124, 123)', 'text': '元坦'},
#      'hurtTransRate': 0.85,
#      'totalHurtCnt': 241662,
#      'totalHeroHurtCnt': 50904,
#      'totalBeHurtCnt': 126823,
#      'beHurtPerDeath': 44058,
#      'trend': 0,
#      'type': [4, 5, 1],
#      'updateId': 12345,
#      'usedtime': 13.68,
#      'winMvpRate': 8.16,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.03, 0.03],
#      'allPickRate': 0.47,
#      'allWinRate': '--',
#      'allBPRate': 0.5,
#      'allScore': 19.06,
#      'allBrandRate': 14.89,
#      'allMvpRate': 12.76,
#      'avgNewScore': 2073,
#      'assistCnt': 5,
#      'deadCnt': 3.76,
#      'totalPrice': 8346,
#      'totalPriceMin': 609,
#      'evaluateGoldRate': 4.25,
#      'evaluateSilverRate': 10.63,
#      'gradient': None,
#      'id': 166,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/166/166.jpg',
#      'joinGamePercent': 56.15,
#      'killCnt': 2.95,
#      'loseMvpRate': 4.25,
#      'name': '亚瑟',
#      'cName': '大宝剑|ys',
#      'skill': [{'id': 80108,
#        'img': '//camp.qq.com/images/skill/80108.png',
#        'pickRate': 93},
#       {'id': 1336,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1336.jpg',
#        'pickRate': 44}],
#      'tag': [],
#      'hurtTransRate': 0.81,
#      'totalHurtCnt': 190256,
#      'totalHeroHurtCnt': 47583,
#      'totalBeHurtCnt': 88397,
#      'beHurtPerDeath': 23014,
#      'trend': 0,
#      'type': [1, 0, 0],
#      'updateId': 233689386,
#      'usedtime': 13.69,
#      'winMvpRate': 8.51,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.02, 0.02],
#      'allPickRate': 0.68,
#      'allWinRate': '--',
#      'allBPRate': 0.7,
#      'allScore': 21.23,
#      'allBrandRate': 11.76,
#      'allMvpRate': 7.35,
#      'avgNewScore': 2036,
#      'assistCnt': 5.38,
#      'deadCnt': 3.33,
#      'totalPrice': 8723,
#      'totalPriceMin': 606,
#      'evaluateGoldRate': 1.47,
#      'evaluateSilverRate': 10.29,
#      'gradient': None,
#      'id': 126,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/126/126.jpg',
#      'joinGamePercent': 53.67,
#      'killCnt': 2.07,
#      'loseMvpRate': 5.88,
#      'name': '夏侯惇',
#      'cName': '夏侯|高达|吓猴蹲|xhd',
#      'skill': [{'id': 80104,
#        'img': '//camp.qq.com/images/skill/80104.png',
#        'pickRate': 45},
#       {'id': 1341,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1341.jpg',
#        'pickRate': 44}],
#      'tag': [],
#      'hurtTransRate': 0.9,
#      'totalHurtCnt': 283744,
#      'totalHeroHurtCnt': 58457,
#      'totalBeHurtCnt': 147310,
#      'beHurtPerDeath': 46205,
#      'trend': 0,
#      'type': [1, 4, 0],
#      'updateId': 233694724,
#      'usedtime': 14.37,
#      'winMvpRate': 1.47,
#      'change': {'updateType': 0, 'updateValue': 0}},
#     {'allBanRate': [0.02, 0.02],
#      'allPickRate': 0.23,
#      'allWinRate': '--',
#      'allBPRate': 0.25,
#      'allScore': 28.74,
#      'allBrandRate': 26.08,
#      'allMvpRate': 8.69,
#      'avgNewScore': 2036,
#      'assistCnt': 3.6,
#      'deadCnt': 2.95,
#      'totalPrice': 8273,
#      'totalPriceMin': 659,
#      'evaluateGoldRate': 13.04,
#      'evaluateSilverRate': 13.04,
#      'gradient': None,
#      'id': 144,
#      'img': '//game.gtimg.cn/images/yxzj/img201606/heroimg/144/144.jpg',
#      'joinGamePercent': 45.27,
#      'killCnt': 2.69,
#      'loseMvpRate': 0,
#      'name': '程咬金',
#      'cName': '金金|小金金|cyj',
#      'skill': [{'id': 80108,
#        'img': '//camp.qq.com/images/skill/80108.png',
#        'pickRate': 91},
#       {'id': 1331,
#        'img': '//game.gtimg.cn/images/yxzj/img201606/itemimg/1331.jpg',
#        'pickRate': 73}],
#      'tag': [],
#      'hurtTransRate': 0.91,
#      'totalHurtCnt': 223734,
#      'totalHeroHurtCnt': 53634,
#      'totalBeHurtCnt': 122953,
#      'beHurtPerDeath': 42700,
#      'trend': 0,
#      'type': [1, 0, 0],
#      'updateId': 233690973,
#      'usedtime': 12.54,
#      'winMvpRate': 8.69,
#      'change': {'updateType': 0, 'updateValue': 0}}]}},
#  'status': {'code': 200,
#   'msg': '操作成功',
#   'usedtime': 0.014,
#   'cache': False,
#   'requestId': 'e815959c7008c0ba103cec25460712e5',
#   'loginId': 0,
#   'icp': '沪ICP备16031287号-2'},
#  'hello': {'_docs': '介绍文档 -> https://91m.top/s/docs',
#   '_tips': '数据来源公开对局，个人学习上分使用，一切请以官方为准。如需调用接口，联系小助理：tiYn78u5pr4ra6oFy',
#   'serverId': 'f528764d624db129'}}

# %%
json_normalize(data_res2['data']['result']['rows']).head(5).T
# Out:
#                                                                     0  \
# allBanRate                                             [60.94, 52.02]
# allPickRate                                                     33.62
# allWinRate                                                      51.87
# allBPRate                                                       85.64
# allScore                                                        158.2
# allBrandRate                                                    20.68
# allMvpRate                                                      16.63
# avgNewScore                                                      2089
# assistCnt                                                        4.73
# deadCnt                                                          2.88
# totalPrice                                                       9326
# totalPriceMin                                                     688
# evaluateGoldRate                                                 4.67
# evaluateSilverRate                                              16.01
# gradient                                                         None
# id                                                                128
# img                 //game.gtimg.cn/images/yxzj/img201606/heroimg/...
# joinGamePercent                                                 53.34
# killCnt                                                          2.88
# loseMvpRate                                                      7.29
# name                                                               曹操
# cName                                                   曹尺|曹三磕|曹老板|cc
# skill               [{'id': 80115, 'img': '//camp.qq.com/images/sk...
# tag                                                                []
# hurtTransRate                                                    0.99
# totalHurtCnt                                                   308182
# totalHeroHurtCnt                                                68446
# totalBeHurtCnt                                                  94391
# beHurtPerDeath                                                  32671
# trend                                                               2
# type                                                        [1, 0, 0]
# updateId                                                    233692400
# usedtime                                                        13.55
# winMvpRate                                                       9.34
# change.updateType                                                   1
# change.updateValue                                               2.21
# tag.color                                                         NaN
# tag.text                                                          NaN
#
#                                                                     1  \
# allBanRate                                             [26.73, 25.01]
# allPickRate                                                     24.31
# allWinRate                                                      50.86
# allBPRate                                                       49.32
# allScore                                                       105.33
# allBrandRate                                                    21.48
# allMvpRate                                                      16.29
# avgNewScore                                                      2081
# assistCnt                                                        4.34
# deadCnt                                                          2.92
# totalPrice                                                       9386
# totalPriceMin                                                     676
# evaluateGoldRate                                                 4.27
# evaluateSilverRate                                               17.2
# gradient                                                         None
# id                                                                178
# img                 //game.gtimg.cn/images/yxzj/img201606/heroimg/...
# joinGamePercent                                                  55.4
# killCnt                                                          3.64
# loseMvpRate                                                      7.32
# name                                                               杨戬
# cName                                                      二郎神|哮天犬|yj
# skill               [{'id': 80115, 'img': '//camp.qq.com/images/sk...
# tag                                                                []
# hurtTransRate                                                     1.0
# totalHurtCnt                                                   346860
# totalHeroHurtCnt                                                69540
# totalBeHurtCnt                                                  93225
# beHurtPerDeath                                                  31617
# trend                                                               2
# type                                                        [1, 4, 0]
# updateId                                                    233695316
# usedtime                                                        13.86
# winMvpRate                                                       8.97
# change.updateType                                                   0
# change.updateValue                                                0.0
# tag.color                                                         NaN
# tag.text                                                          NaN
#
#                                                                     2  \
# allBanRate                                              [10.17, 9.88]
# allPickRate                                                     27.51
# allWinRate                                                      48.72
# allBPRate                                                       37.39
# allScore                                                        91.75
# allBrandRate                                                    24.18
# allMvpRate                                                      11.56
# avgNewScore                                                      2081
# assistCnt                                                        5.24
# deadCnt                                                          2.83
# totalPrice                                                       8485
# totalPriceMin                                                     631
# evaluateGoldRate                                                 6.14
# evaluateSilverRate                                              18.03
# gradient                                                         None
# id                                                                503
# img                 //game.gtimg.cn/images/yxzj/img201606/heroimg/...
# joinGamePercent                                                 50.59
# killCnt                                                          1.69
# loseMvpRate                                                      6.65
# name                                                               狂铁
# cName                                                        狂贴|铁子|kt
# skill               [{'id': 80115, 'img': '//camp.qq.com/images/sk...
# tag                                                                []
# hurtTransRate                                                    0.87
# totalHurtCnt                                                   231459
# totalHeroHurtCnt                                                53585
# totalBeHurtCnt                                                 122522
# beHurtPerDeath                                                  43545
# trend                                                               2
# type                                                        [1, 0, 0]
# updateId                                                    272986391
# usedtime                                                        13.43
# winMvpRate                                                        4.9
# change.updateType                                                   1
# change.updateValue                                               1.12
# tag.color                                                         NaN
# tag.text                                                          NaN
#
#                                                                     3  \
# allBanRate                                               [4.98, 4.89]
# allPickRate                                                     24.63
# allWinRate                                                      50.52
# allBPRate                                                       29.52
# allScore                                                        80.64
# allBrandRate                                                    35.54
# allMvpRate                                                       26.4
# avgNewScore                                                      2093
# assistCnt                                                        4.19
# deadCnt                                                          2.62
# totalPrice                                                      10535
# totalPriceMin                                                     775
# evaluateGoldRate                                                 8.93
# evaluateSilverRate                                               26.6
# gradient                                                         None
# id                                                                518
# img                 //game.gtimg.cn/images/yxzj/img201606/heroimg/...
# joinGamePercent                                                 57.61
# killCnt                                                          3.86
# loseMvpRate                                                      10.8
# name                                                               马超
# cName                                         神威|马子|马车|插秧|插秧王|电光马子|mc
# skill               [{'id': 80104, 'img': '//camp.qq.com/images/sk...
# tag                                                                []
# hurtTransRate                                                    0.87
# totalHurtCnt                                                   469046
# totalHeroHurtCnt                                                66417
# totalBeHurtCnt                                                  82325
# beHurtPerDeath                                                  29372
# trend                                                               0
# type                                                        [4, 1, 0]
# updateId                                                    358740390
# usedtime                                                        13.58
# winMvpRate                                                      15.59
# change.updateType                                                   0
# change.updateValue                                                0.0
# tag.color                                                         NaN
# tag.text                                                          NaN
#
#                                                                     4
# allBanRate                                               [8.06, 7.92]
# allPickRate                                                     14.48
# allWinRate                                                      51.51
# allBPRate                                                        22.4
# allScore                                                        64.64
# allBrandRate                                                    26.79
# allMvpRate                                                      21.61
# avgNewScore                                                      2071
# assistCnt                                                         4.7
# deadCnt                                                          2.26
# totalPrice                                                       9317
# totalPriceMin                                                     664
# evaluateGoldRate                                                 5.52
# evaluateSilverRate                                              21.27
# gradient                                                         None
# id                                                                125
# img                 //game.gtimg.cn/images/yxzj/img201606/heroimg/...
# joinGamePercent                                                  54.0
# killCnt                                                          3.22
# loseMvpRate                                                     11.74
# name                                                               元歌
# cName                                                     庞统|傀儡|甜筒|yg
# skill               [{'id': 80115, 'img': '//camp.qq.com/images/sk...
# tag                                                                []
# hurtTransRate                                                    1.03
# totalHurtCnt                                                   267873
# totalHeroHurtCnt                                                71774
# totalBeHurtCnt                                                  50184
# beHurtPerDeath                                                  21570
# trend                                                               1
# type                                                        [1, 0, 0]
# updateId                                                    284211343
# usedtime                                                        14.02
# winMvpRate                                                       9.87
# change.updateType                                                   0
# change.updateValue                                                0.0
# tag.color                                                         NaN
# tag.text                                                          NaN

# %%
data_res['hello']
# Out:
# {'_tips': '所有数据仅用作个人学习，并不代表官方，一切以官方为准。',
#  'docs': '介绍文档 -> https://91m.top/s/docs'}

# %%
data_res.keys()
# Out:
# dict_keys(['data', 'status', 'hello'])

# %%
data_res['data']['result']['rows']
# Out:
# [{'equipment': {'list': [1533, 1425, 1137, 1223, 0, 0], 'allMoney': 5948},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '3/3/4',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=137577&relaySvrId=-1121967328&gameSeq=1733759183&pvpType=5&acntCamp=1&battleType=32&roleId=2472793501&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 385138575,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733759183&relaysvrentity=-1121967328&gamesvrentity=137577&playerid=385138575',
#   'status': 'success',
#   'time': '2024-12-09 23:46:23',
#   'usedtime': 8.15,
#   'userId': 1716535900,
#   'roleId': 2472793501},
#  {'equipment': {'list': [1533, 1137, 1422, 1134, 1121, 0], 'allMoney': 8265},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '2/0/8',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=242266&relaySvrId=452985649&gameSeq=1733759122&pvpType=5&acntCamp=1&battleType=32&roleId=2307587875&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 75992711,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733759122&relaysvrentity=452985649&gamesvrentity=242266&playerid=75992711',
#   'status': 'success',
#   'time': '2024-12-09 23:45:22',
#   'usedtime': 9.03,
#   'userId': 1878834067,
#   'roleId': 2307587875},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1131, 1345],
#    'allMoney': 10277},
#   'gamePlayerName': '[蓝方] 网抑云城小南',
#   'heroId': 531,
#   'heroKda': '7/1/9',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=238516&relaySvrId=-318758096&gameSeq=1733759090&pvpType=5&acntCamp=1&battleType=32&roleId=4081658316&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 1856890797,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733759090&relaysvrentity=-318758096&gamesvrentity=238516&playerid=1856890797',
#   'status': 'success',
#   'time': '2024-12-09 23:44:50',
#   'usedtime': 11.93,
#   'userId': 1610085880,
#   'roleId': 4081658316},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1345, 1121],
#    'allMoney': 10388},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '4/4/4',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=236702&relaySvrId=438313760&gameSeq=1733759083&pvpType=5&acntCamp=1&battleType=32&roleId=127288829&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 1751044923,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733759083&relaysvrentity=438313760&gamesvrentity=236702&playerid=1751044923',
#   'status': 'danger',
#   'time': '2024-12-09 23:44:43',
#   'usedtime': 14.15,
#   'userId': 330758694,
#   'roleId': 127288829},
#  {'equipment': {'list': [1533, 1131, 1137, 1333, 1134, 1138],
#    'allMoney': 17723},
#   'gamePlayerName': '[红方] ',
#   'heroId': 531,
#   'heroKda': '15/5/5',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=238287&relaySvrId=-1472191728&gameSeq=1733759061&pvpType=5&acntCamp=2&battleType=32&roleId=880956045&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 1186551959,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733759061&relaysvrentity=-1472191728&gamesvrentity=238287&playerid=1186551959',
#   'status': 'danger',
#   'time': '2024-12-09 23:44:21',
#   'usedtime': 21.25,
#   'userId': 1874395978,
#   'roleId': 880956045},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1138, 1323],
#    'allMoney': 11626},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '4/1/7',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=237669&relaySvrId=-1897905648&gameSeq=1733759050&pvpType=5&acntCamp=1&battleType=32&roleId=189948687&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 1951699167,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733759050&relaysvrentity=-1897905648&gamesvrentity=237669&playerid=1951699167',
#   'status': 'success',
#   'time': '2024-12-09 23:44:10',
#   'usedtime': 13.78,
#   'userId': 99148857,
#   'roleId': 189948687},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 0, 0], 'allMoney': 7100},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '3/6/3',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=222824&relaySvrId=369148688&gameSeq=1733759043&pvpType=5&acntCamp=1&battleType=32&roleId=138765977&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 204005814,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733759043&relaysvrentity=369148688&gamesvrentity=222824&playerid=204005814',
#   'status': 'danger',
#   'time': '2024-12-09 23:44:03',
#   'usedtime': 9.9,
#   'userId': 349982734,
#   'roleId': 138765977},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1138, 1111],
#    'allMoney': 10474},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '4/2/8',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=237103&relaySvrId=-1256185056&gameSeq=1733759033&pvpType=5&acntCamp=1&battleType=32&roleId=3780742638&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 888187490,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733759033&relaysvrentity=-1256185056&gamesvrentity=237103&playerid=888187490',
#   'status': 'success',
#   'time': '2024-12-09 23:43:53',
#   'usedtime': 12.93,
#   'userId': 1873646347,
#   'roleId': 3780742638},
#  {'equipment': {'list': [1523, 1422, 1137, 1138, 1116, 1115],
#    'allMoney': 7603},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '4/5/2',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=252814&relaySvrId=752886336&gameSeq=1733759019&pvpType=5&acntCamp=1&battleType=32&roleId=1085386770&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 1176359978,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733759019&relaysvrentity=752886336&gamesvrentity=252814&playerid=1176359978',
#   'status': 'danger',
#   'time': '2024-12-09 23:43:39',
#   'usedtime': 11,
#   'userId': 1857191013,
#   'roleId': 1085386770},
#  {'equipment': {'list': [1533, 1137, 1422, 1134, 1138, 1335],
#    'allMoney': 12869},
#   'gamePlayerName': '[红方] ',
#   'heroId': 531,
#   'heroKda': '8/1/2',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=238200&relaySvrId=322978576&gameSeq=1733759006&pvpType=5&acntCamp=2&battleType=32&roleId=795560754&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 131832168,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733759006&relaysvrentity=322978576&gamesvrentity=238200&playerid=131832168',
#   'status': 'danger',
#   'time': '2024-12-09 23:43:26',
#   'usedtime': 14.46,
#   'userId': 1739790159,
#   'roleId': 795560754},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1138, 1124],
#    'allMoney': 11757},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '9/1/7',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=237892&relaySvrId=-1491066096&gameSeq=1733758979&pvpType=5&acntCamp=1&battleType=32&roleId=2915262769&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 1615996562,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758979&relaysvrentity=-1491066096&gamesvrentity=237892&playerid=1615996562',
#   'status': 'success',
#   'time': '2024-12-09 23:42:59',
#   'usedtime': 12.6,
#   'userId': 1795594895,
#   'roleId': 2915262769},
#  {'equipment': {'list': [1533, 1137, 1422, 1134, 1138, 1131],
#    'allMoney': 13015},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '6/2/1',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=237945&relaySvrId=121651984&gameSeq=1733758968&pvpType=5&acntCamp=1&battleType=32&roleId=846169082&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 139106492,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758968&relaysvrentity=121651984&gamesvrentity=237945&playerid=139106492',
#   'status': 'danger',
#   'time': '2024-12-09 23:42:48',
#   'usedtime': 16.1,
#   'userId': 2119571453,
#   'roleId': 846169082},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1111, 1111],
#    'allMoney': 7696},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '0/3/0',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=241710&relaySvrId=33555249&gameSeq=1733758951&pvpType=5&acntCamp=1&battleType=32&roleId=3563164137&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 1839038791,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758951&relaysvrentity=33555249&gamesvrentity=241710&playerid=1839038791',
#   'status': 'danger',
#   'time': '2024-12-09 23:42:31',
#   'usedtime': 11.28,
#   'userId': 1702973706,
#   'roleId': 3563164137},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1325, 1138],
#    'allMoney': 10586},
#   'gamePlayerName': '[红方] ',
#   'heroId': 531,
#   'heroKda': '6/2/1',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=241950&relaySvrId=272630577&gameSeq=1733758944&pvpType=5&acntCamp=2&battleType=32&roleId=1178025719&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 209988606,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758944&relaysvrentity=272630577&gamesvrentity=241950&playerid=209988606',
#   'status': 'success',
#   'time': '2024-12-09 23:42:24',
#   'usedtime': 13.38,
#   'userId': 429189660,
#   'roleId': 1178025719},
#  {'equipment': {'list': [1533, 1422, 1137, 1338, 1134, 1138],
#    'allMoney': 12004},
#   'gamePlayerName': '[红方] 特特布乐',
#   'heroId': 531,
#   'heroKda': '10/1/6',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=269494&relaySvrId=1073775376&gameSeq=1733758942&pvpType=5&acntCamp=2&battleType=32&roleId=153651001&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 0,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758942&relaysvrentity=1073775376&gamesvrentity=269494&playerid=0',
#   'status': 'success',
#   'time': '2024-12-09 23:42:22',
#   'usedtime': 13.75,
#   'userId': 74631992,
#   'roleId': 153651001},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1121, 1111],
#    'allMoney': 8513},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '5/4/4',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=242218&relaySvrId=1140851505&gameSeq=1733758920&pvpType=5&acntCamp=1&battleType=32&roleId=3907412011&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 570252288,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758920&relaysvrentity=1140851505&gamesvrentity=242218&playerid=570252288',
#   'status': 'danger',
#   'time': '2024-12-09 23:42:00',
#   'usedtime': 11.46,
#   'userId': 1712080991,
#   'roleId': 3907412011},
#  {'equipment': {'list': [1523, 1422, 1137, 1116, 0, 0], 'allMoney': 4113},
#   'gamePlayerName': '[蓝方] 杀死回忆32',
#   'heroId': 531,
#   'heroKda': '1/2/1',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=237438&relaySvrId=-1321196736&gameSeq=1733758881&pvpType=5&acntCamp=1&battleType=32&roleId=1999154185&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 324694427,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758881&relaysvrentity=-1321196736&gamesvrentity=237438&playerid=324694427',
#   'status': 'danger',
#   'time': '2024-12-09 23:41:21',
#   'usedtime': 6.73,
#   'userId': 529607971,
#   'roleId': 1999154185},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1121, 1111],
#    'allMoney': 8711},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '4/7/6',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=238458&relaySvrId=503333648&gameSeq=1733758841&pvpType=5&acntCamp=1&battleType=32&roleId=3663332929&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 1368249494,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758841&relaysvrentity=503333648&gamesvrentity=238458&playerid=1368249494',
#   'status': 'danger',
#   'time': '2024-12-09 23:40:41',
#   'usedtime': 14.18,
#   'userId': 1742461554,
#   'roleId': 3663332929},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1138, 11311],
#    'allMoney': 20374},
#   'gamePlayerName': '[蓝方] 皮卡闪电云',
#   'heroId': 531,
#   'heroKda': '6/4/3',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=237849&relaySvrId=350233120&gameSeq=1733758799&pvpType=5&acntCamp=1&battleType=32&roleId=129535614&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 0,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758799&relaysvrentity=350233120&gamesvrentity=237849&playerid=0',
#   'status': 'danger',
#   'time': '2024-12-09 23:39:59',
#   'usedtime': 28.3,
#   'userId': 70504821,
#   'roleId': 129535614},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1121, 1121],
#    'allMoney': 9093},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '5/4/1',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=269500&relaySvrId=1157686032&gameSeq=1733758752&pvpType=5&acntCamp=1&battleType=32&roleId=792403035&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 913448253,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758752&relaysvrentity=1157686032&gamesvrentity=269500&playerid=913448253',
#   'status': 'danger',
#   'time': '2024-12-09 23:39:12',
#   'usedtime': 12.3,
#   'userId': 462831574,
#   'roleId': 792403035},
#  {'equipment': {'list': [1523, 1421, 1137, 1134, 1131, 0], 'allMoney': 8052},
#   'gamePlayerName': '[红方] ',
#   'heroId': 531,
#   'heroKda': '3/6/2',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=238314&relaySvrId=155206416&gameSeq=1733758688&pvpType=5&acntCamp=2&battleType=32&roleId=976215833&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 1182843499,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758688&relaysvrentity=155206416&gamesvrentity=238314&playerid=1182843499',
#   'status': 'danger',
#   'time': '2024-12-09 23:38:08',
#   'usedtime': 12.2,
#   'userId': 480677405,
#   'roleId': 976215833},
#  {'equipment': {'list': [1533, 1137, 1422, 1134, 1121, 0], 'allMoney': 7946},
#   'gamePlayerName': '[蓝方] ',
#   'heroId': 531,
#   'heroKda': '0/1/1',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=241935&relaySvrId=-1790926032&gameSeq=1733758664&pvpType=5&acntCamp=1&battleType=32&roleId=1986383739&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 867405573,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758664&relaysvrentity=-1790926032&gamesvrentity=241935&playerid=867405573',
#   'status': 'danger',
#   'time': '2024-12-09 23:37:44',
#   'usedtime': 11.95,
#   'userId': 497938033,
#   'roleId': 1986383739},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1131, 1325],
#    'allMoney': 10397},
#   'gamePlayerName': '[红方] ',
#   'heroId': 531,
#   'heroKda': '2/4/5',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=223487&relaySvrId=-1237302512&gameSeq=1733758660&pvpType=5&acntCamp=2&battleType=32&roleId=4078055167&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 1865809045,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758660&relaysvrentity=-1237302512&gamesvrentity=223487&playerid=1865809045',
#   'status': 'danger',
#   'time': '2024-12-09 23:37:40',
#   'usedtime': 15.8,
#   'userId': 478498642,
#   'roleId': 4078055167},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1121, 1121],
#    'allMoney': 9430},
#   'gamePlayerName': '[红方] ',
#   'heroId': 531,
#   'heroKda': '4/1/5',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=222855&relaySvrId=467673616&gameSeq=1733758645&pvpType=5&acntCamp=2&battleType=32&roleId=1645783130&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 563319569,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758645&relaysvrentity=467673616&gamesvrentity=222855&playerid=563319569',
#   'status': 'success',
#   'time': '2024-12-09 23:37:25',
#   'usedtime': 9.76,
#   'userId': 539524870,
#   'roleId': 1645783130},
#  {'equipment': {'list': [1533, 1422, 1137, 1134, 1124, 0], 'allMoney': 8074},
#   'gamePlayerName': '[蓝方] 月下有沐',
#   'heroId': 531,
#   'heroKda': '2/5/1',
#   'heroSkill': 80104,
#   'heroPosition': '打野',
#   'hippyUrl': 'smobagamehelper://hippy?modulename=battle&path=/battleDetailNew&gameSvrId=252435&relaySvrId=165691952&gameSeq=1733758643&pvpType=5&acntCamp=1&battleType=32&roleId=3206441762&hasWsReport=0&matchGametype=14&matchGameResult=1&gameType=HoK&gameOpenId=&supportPro=31',
#   'playerId': 2073159611,
#   'replayUrl': 'https://image.ttwz.qq.com/h5/webdist/battle-replay.html?isNavigationBarHidden=1&gameseq=1733758643&relaysvrentity=165691952&gamesvrentity=252435&playerid=2073159611',
#   'status': 'danger',
#   'time': '2024-12-09 23:37:23',
#   'usedtime': 13.1,
#   'userId': 1848032487,
#   'roleId': 3206441762}]

# %%
data = json_normalize(data_res['data']['result']['rows'])

# %%
data
# Out:
#    gamePlayerName  heroId heroKda  heroSkill heroPosition  \
# 0           [蓝方]      531   3/3/4      80104           打野
# 1           [蓝方]      531   2/0/8      80104           打野
# 2     [蓝方] 网抑云城小南     531   7/1/9      80104           打野
# 3           [蓝方]      531   4/4/4      80104           打野
# 4           [红方]      531  15/5/5      80104           打野
# 5           [蓝方]      531   4/1/7      80104           打野
# 6           [蓝方]      531   3/6/3      80104           打野
# 7           [蓝方]      531   4/2/8      80104           打野
# 8           [蓝方]      531   4/5/2      80104           打野
# 9           [红方]      531   8/1/2      80104           打野
# 10          [蓝方]      531   9/1/7      80104           打野
# 11          [蓝方]      531   6/2/1      80104           打野
# 12          [蓝方]      531   0/3/0      80104           打野
# 13          [红方]      531   6/2/1      80104           打野
# 14      [红方] 特特布乐     531  10/1/6      80104           打野
# 15          [蓝方]      531   5/4/4      80104           打野
# 16    [蓝方] 杀死回忆32     531   1/2/1      80104           打野
# 17          [蓝方]      531   4/7/6      80104           打野
# 18     [蓝方] 皮卡闪电云     531   6/4/3      80104           打野
# 19          [蓝方]      531   5/4/1      80104           打野
# 20          [红方]      531   3/6/2      80104           打野
# 21          [蓝方]      531   0/1/1      80104           打野
# 22          [红方]      531   2/4/5      80104           打野
# 23          [红方]      531   4/1/5      80104           打野
# 24      [蓝方] 月下有沐     531   2/5/1      80104           打野
#
#                                              hippyUrl    playerId  \
# 0   smobagamehelper://hippy?modulename=battle&path...   385138575
# 1   smobagamehelper://hippy?modulename=battle&path...    75992711
# 2   smobagamehelper://hippy?modulename=battle&path...  1856890797
# 3   smobagamehelper://hippy?modulename=battle&path...  1751044923
# 4   smobagamehelper://hippy?modulename=battle&path...  1186551959
# 5   smobagamehelper://hippy?modulename=battle&path...  1951699167
# 6   smobagamehelper://hippy?modulename=battle&path...   204005814
# 7   smobagamehelper://hippy?modulename=battle&path...   888187490
# 8   smobagamehelper://hippy?modulename=battle&path...  1176359978
# 9   smobagamehelper://hippy?modulename=battle&path...   131832168
# 10  smobagamehelper://hippy?modulename=battle&path...  1615996562
# 11  smobagamehelper://hippy?modulename=battle&path...   139106492
# 12  smobagamehelper://hippy?modulename=battle&path...  1839038791
# 13  smobagamehelper://hippy?modulename=battle&path...   209988606
# 14  smobagamehelper://hippy?modulename=battle&path...           0
# 15  smobagamehelper://hippy?modulename=battle&path...   570252288
# 16  smobagamehelper://hippy?modulename=battle&path...   324694427
# 17  smobagamehelper://hippy?modulename=battle&path...  1368249494
# 18  smobagamehelper://hippy?modulename=battle&path...           0
# 19  smobagamehelper://hippy?modulename=battle&path...   913448253
# 20  smobagamehelper://hippy?modulename=battle&path...  1182843499
# 21  smobagamehelper://hippy?modulename=battle&path...   867405573
# 22  smobagamehelper://hippy?modulename=battle&path...  1865809045
# 23  smobagamehelper://hippy?modulename=battle&path...   563319569
# 24  smobagamehelper://hippy?modulename=battle&path...  2073159611
#
#                                             replayUrl   status  \
# 0   https://image.ttwz.qq.com/h5/webdist/battle-re...  success
# 1   https://image.ttwz.qq.com/h5/webdist/battle-re...  success
# 2   https://image.ttwz.qq.com/h5/webdist/battle-re...  success
# 3   https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 4   https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 5   https://image.ttwz.qq.com/h5/webdist/battle-re...  success
# 6   https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 7   https://image.ttwz.qq.com/h5/webdist/battle-re...  success
# 8   https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 9   https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 10  https://image.ttwz.qq.com/h5/webdist/battle-re...  success
# 11  https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 12  https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 13  https://image.ttwz.qq.com/h5/webdist/battle-re...  success
# 14  https://image.ttwz.qq.com/h5/webdist/battle-re...  success
# 15  https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 16  https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 17  https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 18  https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 19  https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 20  https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 21  https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 22  https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
# 23  https://image.ttwz.qq.com/h5/webdist/battle-re...  success
# 24  https://image.ttwz.qq.com/h5/webdist/battle-re...   danger
#
#                    time  usedtime      userId      roleId  \
# 0   2024-12-09 23:46:23      8.15  1716535900  2472793501
# 1   2024-12-09 23:45:22      9.03  1878834067  2307587875
# 2   2024-12-09 23:44:50     11.93  1610085880  4081658316
# 3   2024-12-09 23:44:43     14.15   330758694   127288829
# 4   2024-12-09 23:44:21     21.25  1874395978   880956045
# 5   2024-12-09 23:44:10     13.78    99148857   189948687
# 6   2024-12-09 23:44:03      9.90   349982734   138765977
# 7   2024-12-09 23:43:53     12.93  1873646347  3780742638
# 8   2024-12-09 23:43:39     11.00  1857191013  1085386770
# 9   2024-12-09 23:43:26     14.46  1739790159   795560754
# 10  2024-12-09 23:42:59     12.60  1795594895  2915262769
# 11  2024-12-09 23:42:48     16.10  2119571453   846169082
# 12  2024-12-09 23:42:31     11.28  1702973706  3563164137
# 13  2024-12-09 23:42:24     13.38   429189660  1178025719
# 14  2024-12-09 23:42:22     13.75    74631992   153651001
# 15  2024-12-09 23:42:00     11.46  1712080991  3907412011
# 16  2024-12-09 23:41:21      6.73   529607971  1999154185
# 17  2024-12-09 23:40:41     14.18  1742461554  3663332929
# 18  2024-12-09 23:39:59     28.30    70504821   129535614
# 19  2024-12-09 23:39:12     12.30   462831574   792403035
# 20  2024-12-09 23:38:08     12.20   480677405   976215833
# 21  2024-12-09 23:37:44     11.95   497938033  1986383739
# 22  2024-12-09 23:37:40     15.80   478498642  4078055167
# 23  2024-12-09 23:37:25      9.76   539524870  1645783130
# 24  2024-12-09 23:37:23     13.10  1848032487  3206441762
#
#                            equipment.list  equipment.allMoney
# 0          [1533, 1425, 1137, 1223, 0, 0]                5948
# 1       [1533, 1137, 1422, 1134, 1121, 0]                8265
# 2    [1533, 1422, 1137, 1134, 1131, 1345]               10277
# 3    [1533, 1422, 1137, 1134, 1345, 1121]               10388
# 4    [1533, 1131, 1137, 1333, 1134, 1138]               17723
# 5    [1533, 1422, 1137, 1134, 1138, 1323]               11626
# 6          [1533, 1422, 1137, 1134, 0, 0]                7100
# 7    [1533, 1422, 1137, 1134, 1138, 1111]               10474
# 8    [1523, 1422, 1137, 1138, 1116, 1115]                7603
# 9    [1533, 1137, 1422, 1134, 1138, 1335]               12869
# 10   [1533, 1422, 1137, 1134, 1138, 1124]               11757
# 11   [1533, 1137, 1422, 1134, 1138, 1131]               13015
# 12   [1533, 1422, 1137, 1134, 1111, 1111]                7696
# 13   [1533, 1422, 1137, 1134, 1325, 1138]               10586
# 14   [1533, 1422, 1137, 1338, 1134, 1138]               12004
# 15   [1533, 1422, 1137, 1134, 1121, 1111]                8513
# 16         [1523, 1422, 1137, 1116, 0, 0]                4113
# 17   [1533, 1422, 1137, 1134, 1121, 1111]                8711
# 18  [1533, 1422, 1137, 1134, 1138, 11311]               20374
# 19   [1533, 1422, 1137, 1134, 1121, 1121]                9093
# 20      [1523, 1421, 1137, 1134, 1131, 0]                8052
# 21      [1533, 1137, 1422, 1134, 1121, 0]                7946
# 22   [1533, 1422, 1137, 1134, 1131, 1325]               10397
# 23   [1533, 1422, 1137, 1134, 1121, 1121]                9430
# 24      [1533, 1422, 1137, 1134, 1124, 0]                8074
