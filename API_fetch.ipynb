# %%
import requests
from pandas import json_normalize

headers = {
    'User-Agent': 'Apipost client Runtime/+https://www.apipost.cn/',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'zh-CN,zh;q=0.9',
    'content-length': '0',
    'content-type': 'application/x-www-form-urlencoded',
    'origin': 'https://pvp.91m.top',
    'priority': 'u=1, i',
    'referer': 'https://pvp.91m.top/',
    'sec-ch-ua': '"Microsoft Edge";v="143", "Chromium";v="143", "Not A(Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36 Edg/143.0.0.0',
    'Content-Type': 'application/x-www-form-urlencoded',
}

params = (
    ('type', 'getRanking'),
    ('aid', '0'),
    ('bid', '0'),
    ('cid', '4'),
    ('did', '0'),
    ('host', 'pvp.91m.top'),
    ('lang', 'zh-CN'),
    ('ref', ''),
    ('gameType', 'wzry'),
    ('url', 'https://pvp.91m.top/ranking?type=0&bid=0&cid=4&did=0&eid=b&refresh=1'),
    ('urlReal', 'https://pvp.91m.top/ranking?type=0&bid=0&cid=4&did=0&eid=b&refresh=1'),
)

response = requests.get('https://api.91m.top/hero/app', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://api.91m.top/hero/app?type=getRanking&aid=0&bid=0&cid=4&did=0&host=pvp.91m.top&lang=zh-CN&ref=&gameType=wzry&url=https%3A%2F%2Fpvp.91m.top%2Franking%3Ftype%3D0%26bid%3D0%26cid%3D4%26did%3D0%26eid%3Db%26refresh%3D1&urlReal=https%3A%2F%2Fpvp.91m.top%2Franking%3Ftype%3D0%26bid%3D0%26cid%3D4%26did%3D0%26eid%3Db%26refresh%3D1', headers=headers)

# %%
data_rows = response.json()['data']['result']['rows']

# %%
json_normalize(data_rows).T
# Out:
#                                                                    0   \
# allBanRate                                             [101.1, 75.04]
# allPickRate                                                       9.5
# allWinRate                                                      52.32
# allBPRate                                                       84.54
# allScore                                                       138.96
# allBrandRate                                                    34.59
# allMvpRate                                                      36.91
# avgNewScore                                                      2240
# assistCnt                                                        4.85
# deadCnt                                                          2.63
# totalPrice                                                      10527
# totalPriceMin                                                     770
# ...

# %%
import requests

headers = {
    'User-Agent': 'Apipost client Runtime/+https://www.apipost.cn/',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'zh-CN,zh;q=0.9',
    'content-length': '0',
    'content-type': 'application/x-www-form-urlencoded',
    'origin': 'https://pvp.91m.top',
    'priority': 'u=1, i',
    'referer': 'https://pvp.91m.top/',
    'sec-ch-ua': '"Microsoft Edge";v="143", "Chromium";v="143", "Not A(Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36 Edg/143.0.0.0',
    'Content-Type': 'application/x-www-form-urlencoded',
}

params = (
    ('type', 'getRanking'),
    ('aid', '16'),
    ('bid', '0'),
    ('cid', '4'),
    ('did', '0'),
    ('host', 'pvp.91m.top'),
    ('lang', 'zh-CN'),
    ('ref', ''),
    ('gameType', 'wzry'),
    ('url', 'https://pvp.91m.top/ranking?type=0&bid=0&cid=4&did=0&eid=b&refresh=1'),
    ('urlReal', 'https://pvp.91m.top/ranking?type=0&bid=0&cid=4&did=0&eid=b&refresh=1'),
)

response = requests.get('https://api.91m.top/hero/app', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://api.91m.top/hero/app?type=getRanking&aid=16&bid=0&cid=4&did=0&host=pvp.91m.top&lang=zh-CN&ref=&gameType=wzry&url=https%3A%2F%2Fpvp.91m.top%2Franking%3Ftype%3D0%26bid%3D0%26cid%3D4%26did%3D0%26eid%3Db%26refresh%3D1&urlReal=https%3A%2F%2Fpvp.91m.top%2Franking%3Ftype%3D0%26bid%3D0%26cid%3D4%26did%3D0%26eid%3Db%26refresh%3D1', headers=headers)

# %%
data_rows_grad = response.json()['data']['result']['rows']

# %%
json_normalize(data_rows_grad)
# Out:
#      id                                                img     name  trend  \
# 0   531  //game.gtimg.cn/images/yxzj/img201606/heroimg/...        镜      0
# 1   180  //game.gtimg.cn/images/yxzj/img201606/heroimg/...       哪吒      2
# 2   502  //game.gtimg.cn/images/yxzj/img201606/heroimg/...      裴擒虎      0
# 3   518  //game.gtimg.cn/images/yxzj/img201606/heroimg/...       马超      0
# 4   130  //game.gtimg.cn/images/yxzj/img201606/heroimg/...     宫本武藏      1
# 5   190  //game.gtimg.cn/images/yxzj/img201606/heroimg/...      诸葛亮      0
# 6   178  //game.gtimg.cn/images/yxzj/img201606/heroimg/...       杨戬      1
# 7   150  //game.gtimg.cn/images/yxzj/img201606/heroimg/...       韩信      0
# 8   542  //game.gtimg.cn/images/yxzj/img201606/heroimg/...        暃      0
# 9   193  //game.gtimg.cn/images/yxzj/img201606/heroimg/...        铠      0
# 10  538  //game.gtimg.cn/images/yxzj/img201606/heroimg/...       云缨      2
# ...

# %%
json_normalize(data_rows_grad)[['name','gradient','gradientScore']].groupby("gradient").apply(lambda x: x['name'].values) # type: ignore
# Out:
# gradient
# 0.0                                         [镜, 哪吒, 裴擒虎]
# 0.5                                  [马超, 宫本武藏, 诸葛亮, 杨戬]
# 1.0                        [韩信, 暃, 铠, 云缨, 百里玄策, 露娜, 阿古朵]
# 2.0                             [橘右京, 大司命, 李白, 雅典娜, 司马懿]
# 3.0    [典韦, 盘古, 娜可露露, 云中君, 曜, 赵云, 兰陵王, 芈月, 孙悟空, 李元芳, ...
# 4.0                      [梦奇, 刘备, 元流之子_坦克, 夏侯惇, 阿轲, 钟无艳]
# dtype: object

# %%
hero1 = ["镜", "裴擒虎", "马超", " 诸葛亮", "云缨"]
hero2 = ["宫本武藏", "杨戬", "韩信", "暃", "铠"]

# %%
hero1
# Out:
# ['镜', '裴擒虎', '马超', ' 诸葛亮', '云缨']
