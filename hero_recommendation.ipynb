# %%
import numpy as np
import pandas as pd

# %%
total_winrate = {'典韦':49.9,
                 '韩信':48.5,
                 '诸葛':48.8,
                 '宫本':51.9,
                 '老虎':48.5,
                 '澜':49.8,
                 '曜':51.6,
                 '镜':43.5,
                 '铠':52.6,
                 '暃':49.4,
                 '司马懿':48.4,
                 '雅典娜':58.4,
                 '刘备':53.9,
                 '曹操':53.8,
                 '云缨':47.6,
                 '大司命':49.7,
                 '玄策':50.6,
                 '云中君':53.2}

cece_winrate = {'典韦':48.2,
                 '韩信':50.0,
                 '诸葛':51.8,
                 '宫本':51.5,
                 '老虎':51.8,
                 '澜':48.8,
                 '曜':51.8,
                 '镜':50.0,
                 '铠':51.1,
                 '暃':51.4,
                 '司马懿':47.4,
                 '雅典娜':55.4,
                 '刘备':51.5,
                 '曹操':53.5,
                 '云缨':49.5,
                 '大司命':47.1,
                 '玄策':52.0,
                 '云中君':51.3}

personal_winrate = {'典韦':59.5,
                 '韩信':55.5,
                 '诸葛':52.7,
                 '宫本':54.0,
                 '老虎':50.5,
                 '澜':52.0,
                 '曜':54.2,
                 '镜':48.5,
                 '铠':55.5,
                 '暃':51.0,
                 '司马懿':50.0,
                 '雅典娜':60.0,
                 '刘备':51.1,
                 '曹操':62.5,
                 '云缨':55.6,
                 '大司命':49.7,
                 '玄策':56.9,
                 '云中君':58.1}

rivial_power = {'典韦':2535,
                 '韩信':3106,
                 '诸葛':2505,
                 '宫本':2985,
                 '老虎':2149,
                 '澜':2856,
                 '曜':2964,
                 '镜':3145,
                 '铠':2144,
                 '暃':3317,
                 '司马懿':2302,
                 '雅典娜':2612,
                 '刘备':887,
                 '曹操':324,
                 '云缨':757,
                 '大司命':1585,
                 '玄策':70,
                 '云中君':70}

# %%
### S40:打野英雄梯度：
# AD刺：镜 虎 暃 韩信 澜 曜 
# 法刺：诸葛 司马懿
# 战：宫本 铠 大司命 曹操 杨戬

# 勇者+1 史诗+3 传说+5 典藏+6 无双+9
# 星元+2 限定+1 臻品+2

# 皮肤：
# '典韦': 岱宗-史诗限定 (4)
# '韩信':  街头霸王-勇者+星元, 飞衡-史诗限定, 傲雪梅枪-史诗限定, 弑枪猎影-典藏, 群星魔术团-无双 (26)
# '诸葛': 武陵仙君-传说限定, 白泽-无双 (15)
# '宫本': 鬼剑武藏-史诗, 惊梅引-传说, 地狱之眼-传说+星元. 黑崎一护-臻品传说  (22)
# '老虎': 李小龙-史诗限定, 祥瑞亨通-fmvp, 寅虎·赤拳-传说限定 (15)
# '澜': 赏金猎手-史诗, 逐花归海-fmvp, 愿照·九州拓-传说限定 (14)
# '曜': 李逍遥-传说限定, 器灵·璃龙剑-无双 (15)
# '镜': 匿光追影者-史诗限定, 炽阳神光-fmvp (9)
# '铠': 曙光守护者-史诗, 银白咏叹调-典藏 (9)
# '暃': 星界游侠-史诗, 朽木白哉-臻品传说 (10)
# '司马懿': 暗渊魔法-史诗, 九山相柳-传说限定 (9)
# '雅典娜': 神奇女侠-史诗限定 (4)
# '刘备': 百相守梦-史诗限定, 时之恋人-传说+星元 (11)
# '曹操': 海盗船长-史诗 (3)
# '云缨': 传说, 赞萌露比-史诗 (8)
# '大司命': 东方月初-史诗限定, 死亡执政官-传说限定 (10)
# '玄策': 白虎志-传说限定 (6)
# '云中君': 群星魔术团-传说限定 (6)

hero_skin = {'典韦':4,
                 '韩信':26,
                 '诸葛':15,
                 '宫本':22,
                 '老虎':15,
                 '澜':14,
                 '曜':15,
                 '镜':9,
                 '铠':9,
                 '暃':10,
                 '司马懿':9,
                 '雅典娜':4,
                 '刘备':11,
                 '曹操':3,
                 '云缨':8,
                 '大司命':10,
                 '玄策':6,
                 '云中君':6}

# %%
analysis_df = pd.DataFrame({'全分段':total_winrate,'策策':cece_winrate,'个人':personal_winrate,'皮肤':hero_skin,'战力':rivial_power})

# %%
weight_list = [0.1,0.2,0.25,0.2,0.25]

# %%
'、'.join(list(analysis_df.sort_values(by = '战力',ascending=False).index))
# Out:
# '暃、镜、韩信、宫本、曜、澜、雅典娜、典韦、诸葛、司马懿、老虎、铠、大司命、刘备、云缨、曹操、玄策、云中君'

# %%
rank_df = pd.concat([\
analysis_df.apply(lambda x:(x-x.mean())/x.std(),axis=0).dot(weight_list).sort_values(ascending=False).to_frame('RC'),\
analysis_df.rank().dot(weight_list).sort_values().to_frame('RankRC')],axis=1)

# %%
hero_index = analysis_df.sort_values(by='战力',ascending=False).index

# %%
analysis_df.rank().reindex(index=hero_index)
# Out:
#       全分段    策策    个人    皮肤    战力
# 暃     7.0  10.0   5.0  10.5  18.0
# 镜     1.0   6.5   1.0   8.0  17.0
# 韩信    4.5   6.5  11.5  18.0  16.0
# 宫本   13.0  11.5   9.0  17.0  15.0
# 曜    12.0  14.0  10.0  15.0  14.0
# 澜     9.0   4.0   7.0  13.0  13.0
# 雅典娜  18.0  18.0  17.0   2.5  12.0
# 典韦   10.0   3.0  16.0   2.5  11.0
# 诸葛    6.0  14.0   8.0  15.0  10.0
# 司马懿   3.0   2.0   3.0   8.0   9.0
# 老虎    4.5  14.0   4.0  15.0   8.0
# 铠    14.0   8.0  11.5   8.0   7.0
# 大司命   8.0   1.0   2.0  10.5   6.0
# 刘备   17.0  11.5   6.0  12.0   5.0
# 云缨    2.0   5.0  13.0   6.0   4.0
# 曹操   16.0  17.0  18.0   1.0   3.0
# 玄策   11.0  16.0  14.0   4.5   1.5
# 云中君  15.0   9.0  15.0   4.5   1.5

# %%
hero_index
# Out:
# Index(['暃', '镜', '韩信', '宫本', '曜', '澜', '雅典娜', '典韦', '诸葛', '司马懿', '老虎', '铠',
#        '大司命', '刘备', '云缨', '曹操', '玄策', '云中君'],
#       dtype='object')

# %%
analysis_df.sort_values(by='皮肤', ascending=False).head(12)

### S40:打野英雄梯度：
# AD刺：镜（无硬控、无强制位移等）、虎（无突脸爆发、前期弱）、暃（无加盾回血、易斩杀）、韩信（整体笨重怕拉扯）、澜（软辅喜欢抱团）、曜（好切C、能带线） 
# 法刺：诸葛（脆皮多，无抵挡飞行物/不可选中/名刀等机制）、司马懿（对面法术伤害多，软辅）
# 战：宫本（counter回血、短位移：戈娅艾琳）、铠（多段伤害且不灵活）、大司命 杨戬

# 英雄 |          优点                 |         缺点         |
# 镜 | 超远位移、高爆发、双惩机制、地形优势  | 怕硬控 怕强制位移  |
# 虎 | 转线快、前期强、野区压制、手长推塔强  | 怕硬控 怕战士强开 后期弱 |
# 暃 | 绕后点位、强消耗、强收割、手长推塔强  | 发育慢 怕抬血 怕保命装  |
# 韩信 | 单点控制、高爆发、带线牵制、霸体  | 怕爆发 怕锁头 打不动肉  |
# 澜 | 发育快、反野中偏强、适配苍穹、收割能力强  | 怕硬控 打不动肉  |
# 曜 | 带线能力强、高爆发、星削机制、小规模团强  | 怕连环小控 怕定身 难切灵活C  |
# 诸葛 | 滚雪球强、手长、前期2V2强、收割能力强  | 怕突脸强开 怕魔女 怕抵挡飞行物/不可选中/保命机制  |
# 司马懿 | 法师克星、高爆发、进场能力强、带线强  | 依赖队友开 无退场能力 怕小控断大 |
# 宫本 | counter回血 + 短位移：戈娅艾琳、锁头、抵挡飞行物  | 打不动肉 无退场机制  |
# 铠 | 格挡机制counter多段伤害、跑图快、野区越塔强杀  | 怕拉扯 怕爆发 怕摸不到人  |
# 大司命 | 前期巨猛、野区能力强、小规模团强、依赖软辅  | 怕拉扯 怕硬控 怕摸不到人  |
# 杨戬 | 霸体机制、延迟一进场、蹲人强、小规模团战强  | 身板脆 打不动肉 无退场机制  |

# 决策链：
# 战边&软辅 => 战士：偏回复 => 宫本 / 多段伤害 => 铠 / 偏控制+拉扯 => 杨戬 / 笨重+爆发低 => 大司命
# 坦边+软辅：=> 无控制射+强控+强制位移 => 镜 / 中辅弱+好切C => 老虎 / 灵活、无保命 => 暃 / 笨重，缺带线 => 韩信 / 缺控制、缺爆发、艾琳戈娅 => 澜 / 补位 => 曜
# 战边+硬辅：=> 偏分散/脆皮多/手长 => 诸葛 / 偏集中/法师多/怕突脸 => 司马懿

# 对面出射手：
# 游射+控制：公孙离-(宫本、韩信、司马懿) 敖隐-(宫本、韩信、铠) 艾琳-(宫本、澜、司马懿) 戈娅-(宫本、韩信、诸葛)
# 游射+无控制：苍-(澜、铠、镜) 香香-(镜、暃、曜) 守约-(镜、司马懿、宫本) 马可-(镜、铠、宫本) 李元芳-(镜、韩信、宫本) 孙权-(铠、曜、大司命)
# 呆射+站撸：狄仁杰-(铠、镜、大司命) 虞姬-(诸葛、司马懿、铠) 鲁班-(杨戬、宫本、暃) 后羿-(大司命、澜、镜) 蒙犽-(铠、宫本、镜)
# 呆射+非站撸：伽罗-(All) 黄忠 -(All) 

# 法师：火舞 婉儿 貂蝉 高渐离 诸葛 女娲 武则天 小乔 大乔 弈星 昭君 西施 周瑜 姜子牙 米莱狄 安琪拉 妲己 嬴政 干将 杨玉环 嫦娥 炸弹猫 海月 扁鹊 金蝉

# 中辅强度、边野强度、切C难度、野区能力、带线能力
# 中辅强度：前期抢线、进野、中线线权、边路节奏
# 边路2V2：不怎么看手法，只看强度，记住多让对抗路卖 - 打野4级有红蓝决定性更强、最起码1换1，出节奏后赶紧走，不能拖时间
# 打团：绕后 + 蹲草切C
# Out:
#       全分段    策策    个人  皮肤    战力
# 韩信   48.5  50.0  55.5  26  3106
# 宫本   51.9  51.5  54.0  22  2985
# 诸葛   48.8  51.8  52.7  15  2505
# 老虎   48.5  51.8  50.5  15  2149
# 曜    51.6  51.8  54.2  15  2964
# 澜    49.8  48.8  52.0  14  2856
# 刘备   53.9  51.5  51.1  11   887
# 暃    49.4  51.4  51.0  10  3317
# 大司命  49.7  47.1  49.7  10  1585
# 镜    43.5  50.0  48.5   9  3145
# 铠    52.6  51.1  55.5   9  2144
# 司马懿  48.4  47.4  50.0   9  2302

# %%
res1 = pd.concat([analysis_df,rank_df['RC']],axis=1).sort_values(by='RC',ascending=False)
res2 = pd.concat([analysis_df.rank(),rank_df['RankRC']],axis=1).sort_values(by='RankRC',ascending=False)

# %%
list(set(res1.head(10).index).intersection(set(res2.head(10).index)))
# Out:
# ['铠', '暃', '曹操', '宫本', '诸葛', '曜', '雅典娜', '韩信', '老虎']

# %%
res1.head(10)
# Out:
#       全分段    策策    个人  皮肤    战力        RC
# 雅典娜  58.4  55.4  60.0   4  2612  0.954831
# 韩信   48.5  50.0  55.5  26  3106  0.673525
# 宫本   51.9  51.5  54.0  22  2985  0.671770
# 曜    51.6  51.8  54.2  15  2964  0.470555
# 曹操   53.8  53.5  62.5   3   324  0.240465
# 诸葛   48.8  51.8  52.7  15  2505  0.186243
# 铠    52.6  51.1  55.5   9  2144  0.136393
# 暃    49.4  51.4  51.0  10  3317  0.078395
# 老虎   48.5  51.8  50.5  15  2149 -0.041052
# 典韦   49.9  48.2  59.5   4  2535 -0.051015

# %%
res2.head(10)
# Out:
#       全分段    策策    个人    皮肤    战力  RankRC
# 雅典娜  18.0  18.0  17.0   2.5  12.0  13.150
# 宫本   13.0  11.5   9.0  17.0  15.0  13.000
# 曜    12.0  14.0  10.0  15.0  14.0  13.000
# 韩信    4.5   6.5  11.5  18.0  16.0  12.225
# 诸葛    6.0  14.0   8.0  15.0  10.0  10.900
# 暃     7.0  10.0   5.0  10.5  18.0  10.550
# 曹操   16.0  17.0  18.0   1.0   3.0  10.450
# 澜     9.0   4.0   7.0  13.0  13.0   9.300
# 老虎    4.5  14.0   4.0  15.0   8.0   9.250
# 铠    14.0   8.0  11.5   8.0   7.0   9.225

# %%
# 09-04 战绩记录：

# L 23:07
# 马超 9.9 阿古朵 10.9 乔 7.8 香 6.2 朵 9.2 5/1/4
# L 23:29
# 亚连 5.3 马超 4.9 小乔 4.9 狂铁 5.5 空空 3.6 ==> 1/4/1
# W 23:43
# 夏洛特 6.4 阿古朵 7.8 西施 6.2 孙权 11.1 瑶 7.7 6/3/4
# L 00:09
# 马超 8.8 阿古朵 11.7 昭君 7.7 戬 5.5 膑 8.1 12/6/3
# L 00:36
# 夏洛特 8.0 阿古朵 8.1 武则天 12.4 孙权 8.1 膑 9.3 7/7/9 
# 

# zhan xia MAT array Lin
[[9.9,7.8,9.2,10.9,6.2],
[4.9,4.9,3.6,5.3,5.5],
[11.1,7.7,6.2,7.8,6.4],
[8.8,8.1,7.7,11.7,5.5],
[8.1,9.3,12.4,8.1,8.0]]

# %%
import pandas as pd
res_df = pd.DataFrame({'G1':[9.9,7.8,9.2,10.9,6.2],\
              'G2':[4.9,4.9,3.6,5.3,5.5],\
              'G3':[11.1,7.7,6.2,7.8,6.4],\
              'G4':[8.8,8.1,7.7,11.7,5.5],\
              'G5':[8.1,9.3,12.4,8.1,8.0]},index=["Z","X","M","A","L"]).T

# %%
res_df
# Out:
#        Z    X     M     A    L
# G1   9.9  7.8   9.2  10.9  6.2
# G2   4.9  4.9   3.6   5.3  5.5
# G3  11.1  7.7   6.2   7.8  6.4
# G4   8.8  8.1   7.7  11.7  5.5
# G5   8.1  9.3  12.4   8.1  8.0

# %%
res_df.mean()
# Out:
# Z    8.56
# X    7.56
# M    7.82
# A    8.76
# L    6.32
# dtype: float64
